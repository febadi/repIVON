# %%
# %%bash
# sudo apt-get update
# sudo apt-get install -y \
#     texlive \
#     texlive-latex-extra \
#     texlive-fonts-recommended \
#     texlive-fonts-extra \
#     cm-super \
#     dvipng

# %%
import matplotlib as mpl

mpl.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Times"],
    "text.latex.preamble": r"\usepackage{amsmath}",

    # --- FONT SIZE HIERARCHY ---
    "figure.titlesize": 16,
    "axes.titlesize": 14,
    "axes.labelsize": 12,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "legend.fontsize": 11,
    "legend.title_fontsize": 12,
})

# %% [markdown]
# ## Project Goal
#
# The objective of this project is to **reproduce the results of the IVON paper**
# ([Shen et al., 2024](https://proceedings.mlr.press/v235/shen24b.html)).
# IVON presents a refined and elegant synthesis of several influential prior works in adaptive Bayesian optimization and natural gradient methods, including:
#
# - [**Khan et al.**](https://dl.acm.org/doi/abs/10.5555/3648699.3648980)
# - [**Khan & Rue**](https://proceedings.mlr.press/v80/khan18a.html)
# - [**Lin et al.**](https://proceedings.mlr.press/v119/lin20d.html)
# - [**Zhang et al.**](https://dl.acm.org/doi/10.5555/3454287.3454673)
#
# This project aims to carefully reconstruct the experimental setup, methodology, and quantitative findings presented in the paper to ensure a faithful replication.
#
# For deeper context, motivations, and additional explanations, consult:
#
# - https://ysngshn.github.io/research/why-ivon/
# - https://adaptive-bayesian.ai/blog/ivon/
# - https://github.com/team-approx-bayes/ivon-experiments

# %%
# !pip install torch --index-url https://download.pytorch.org/whl/cu118
# !pip install ivon-opt
# Out:
# Collecting ivon-opt
#   Downloading ivon_opt-0.1.3-py3-none-any.whl.metadata (4.8 kB)
# Downloading ivon_opt-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: ivon-opt
# Successfully installed ivon-opt-0.1.3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import ivon
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import sys
import seaborn as sns
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, auc

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
print("Python version:")
print(sys.version)

print("\nPyTorch version:")
print(torch.__version__)
# Out:
# Python version:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
#
# PyTorch version:
# 2.9.0+cu126

# %% [markdown]
# ## Loading, Splitting, and Preparing the CIFAR-10 Dataset
#
# This section loads the CIFAR-10 dataset and applies standard preprocessing used in many deep-learning experiments. CIFAR-10 contains 60,000 color images at 32×32 resolution across 10 classes. For more information, see the official dataset page: [CIFAR-10 Dataset](https://www.cs.toronto.edu/~kriz/cifar.html). We use the standard CIFAR-10 channel-wise mean and standard deviation `(0.4914, 0.4822, 0.4465)` and `(0.2470, 0.2435, 0.2616)` to normalize images, which helps stabilize training by making pixel values more consistent. The dataset is loaded using the `torchvision.datasets.CIFAR10` class documented at: [torchvision CIFAR10](https://docs.pytorch.org/vision/main/generated/torchvision.datasets.CIFAR10.html).
#
# The code below first defines the normalization values, then creates two transform pipelines: a training transform that includes random cropping and horizontal flipping for data augmentation, and a testing transform that applies only tensor conversion and normalization. The training portion of the CIFAR-10 dataset is then loaded twice so we can construct a train/validation split: one version uses the augmented transforms for training, and the other uses the non-augmented transforms for validation. After splitting the dataset into training and validation subsets, we load the test set with only normalization. Finally, we wrap the train, validation, and test datasets in PyTorch `DataLoader` objects with a batch size of 50.
#
# This procedure matches the dataset handling strategy used in the [IVON reference implementation](https://github.com/team-approx-bayes/ivon-experiments/blob/main/common/dataloaders.py).

# %%
NUMB_EPOCHS = 150

# %%
# --- Standard CIFAR-10 normalization ---
mean = (0.4914, 0.4822, 0.4465)
std  = (0.2470, 0.2435, 0.2616)

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# --- Load CIFAR-10 train data (will later be split into train and val) ---
full_train_dataset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    transform=transform_train,   # training transform (with augmentation)
    download=True
)

# --- Create a validation dataset that uses NO augmentation ---
full_val_dataset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    transform=transform_test,    # no augmentation for validation
    download=True
)

# --- Train/Val split ---
train_ratio = 0.9          # e.g., 90% train, 10% validation
n_train = int(len(full_train_dataset) * train_ratio)
n_val = len(full_train_dataset) - n_train

train_dataset, val_dataset = torch.utils.data.random_split(
    full_train_dataset,
    [n_train, n_val],
    generator=torch.Generator().manual_seed(42)   # reproducible split
)

# Replace validation transform
val_dataset.dataset = full_val_dataset

# --- Load CIFAR-10 test data ---
test_dataset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    transform=transform_test,
    download=True
)

# --- DataLoaders (batch_size = 50 to match IVON paper) ---
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=50, shuffle=True)
val_loader   = torch.utils.data.DataLoader(val_dataset,   batch_size=50, shuffle=False)
test_loader  = torch.utils.data.DataLoader(test_dataset,  batch_size=50, shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:10<00:00, 15.8MB/s]

# %% [markdown]
# ## ResNet-20 Implementation
#
# The following code block implements **ResNet-20 exactly as described in the original paper**
# [**Deep Residual Learning for Image Recognition**](https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7780459)
#
# Important clarifications:
#
# - The **original authors did not release their CIFAR-ResNet20 implementation in PyTorch**
#   (their official codebase was in [**Caffe**](https://github.com/KaimingHe/deep-residual-networks)).
# - The **IVON paper** uses “the standard CIFAR-10 20-layer ResNet” from the original work,
#   but does **not** include its own ResNet20 implementation in the repository.
# - Therefore, our implementation follows the **canonical and widely-used PyTorch version**:
#   https://github.com/kuangliu/pytorch-cifar/blob/master/models/resnet.py
#   which is a faithful reproduction of the architecture in the main ResNet paper.
#
# This ensures that our model architecture is **fully aligned** with both the **original ResNet-20 design** and the **model used in IVON experiments**.

# %%
class BasicBlock(nn.Module):
    expansion = 1
    def __init__(self, in_planes, planes, stride=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)

        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        return F.relu(out)

class ResNet20(nn.Module):
    def __init__(self):
        super().__init__()
        self.in_planes = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self._make_layer(16, 3, stride=1)
        self.layer2 = self._make_layer(32, 3, stride=2)
        self.layer3 = self._make_layer(64, 3, stride=2)

        self.avgpool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(64, 10)

    def _make_layer(self, planes, blocks, stride):
        strides = [stride] + [1]*(blocks-1)
        layers = []
        for s in strides:
            layers.append(BasicBlock(self.in_planes, planes, s))
            self.in_planes = planes
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avgpool(out)
        out = torch.flatten(out, 1)
        return self.fc(out)

# %% [markdown]
# # Unified Evaluation & Calibration Metrics
#
# This section provides helper functions for evaluating classification models trained with both **deterministic optimizers** (SGD, AdamW) and **posterior‐sampling optimizers** such as **IVON**.
# The evaluation includes both **accuracy metrics** and **uncertainty metrics**, providing a complete understanding of model behavior.
#
# ---
#
# ## 1. `evaluate_probs()` — Probability Extraction & Posterior Sampling
#
# This function computes model probabilities under different inference regimes:
#
# ### **A. Deterministic Models (SGD, AdamW)**
# Uses fixed model parameters:
#
# $$
# p_i = \operatorname{softmax}(f_\theta(x_i))
# $$
#
# ### **B. IVON@mean (`test_samples = 0`)**
# Uses the **posterior mean** \( m \) as the model parameters:
#
# $$
# \theta = m
# $$
#
# ### **C. IVON Posterior Sampling (`test_samples ≥ 1`)**
#
# - `test_samples = 1` → one posterior sample
# - `test_samples > 1` → Monte Carlo posterior averaging:
#
# $$
# \bar{p}_i =
# \frac{1}{T}
# \sum_{t=1}^{T}
# \operatorname{softmax}(f_{\theta^{(t)}}(x_i))
# $$
#
# The function returns:
# - Predicted probabilities
# - Ground‐truth labels
# - Logits (needed for NLL)
#
# ---
#
# ## 2. `plot_calibration_curve()` — Reliability Diagram
#
# A reliability diagram visualizes how predicted confidence aligns with empirical accuracy.
#
# For each sample \( i \):
#
# - Confidence:
#   $$
#   c_i = \max_k p_{ik}
#   $$
#
# - Predicted class:
#   $$
#   \hat{y}_i = \arg\max_k p_{ik}
#   $$
#
# - Correctness:
#   $$
#   \text{correct}_i =
#   \begin{cases}
#   1, & \hat{y}_i = y_i \\
#   0, & \text{otherwise}
#   \end{cases}
#   $$
#
# Samples are binned by confidence, and for each bin \( B_m \):
#
# $$
# \text{acc}(B_m)
# =
# \frac{1}{|B_m|}
# \sum_{i \in B_m}
# \mathbf{1}[\hat{y}_i = y_i]
# $$
#
# $$
# \text{conf}(B_m)
# =
# \frac{1}{|B_m|}
# \sum_{i \in B_m}
# c_i
# $$
#
# A perfectly calibrated model lies on the diagonal \( y = x \).
#
# ---
#
# ## 3. `compute_ece()` — Expected Calibration Error (ECE)
#
# ECE quantifies the misalignment between confidence and accuracy:
#
# $$
# \text{ECE}
# =
# \sum_{m=1}^{M}
# \frac{|B_m|}{N}
# \,
# \left|
# \text{acc}(B_m)
# -
# \text{conf}(B_m)
# \right|
# $$
#
# Lower ECE means better calibration.
#
# ---
#
# ## 4. `evaluate_all_metrics()` — Comprehensive Evaluation
#
# This function computes both accuracy and uncertainty metrics.
#
# ### **Top-1 Accuracy**
# $$
# \text{Acc@1}
# =
# \frac{1}{N}
# \sum_{i=1}^{N}
# \mathbf{1}[\hat{y}_i = y_i]
# $$
#
# ### **Top-5 Accuracy**
# $$
# \text{Acc@5}
# =
# \frac{1}{N}
# \sum_{i=1}^{N}
# \mathbf{1}[y_i \in \text{Top5}(p_i)]
# $$
#
# ### **Negative Log-Likelihood (NLL)**
# $$
# \text{NLL}
# =
# -\frac{1}{N}
# \sum_{i=1}^{N}
# \log p_{i, y_i}
# $$
#
# ### **Expected Calibration Error (ECE)**
# (as defined above)
#
# ### **Brier Score**
# $$
# \text{Brier}
# =
# \frac{1}{N}
# \sum_{i=1}^{N}
# \sum_{k=1}^{K}
# \left(p_{ik} - \mathbf{1}[y_i = k]\right)^2
# $$
#
# The function returns all metrics plus raw probabilities and labels.
#
# ---
#
# ## 5. `compare_methods()` — Evaluate Multiple Training Methods
#
# This utility evaluates several optimizers under a shared protocol.
#
# ### **Input format**
# ```python
# methods_dict = {
#     "SGD":       (model_sgd, optimizer_sgd, 0),
#     "AdamW":     (model_adam, optimizer_adam, 0),
#     "IVON@mean": (model_ivon, optimizer_ivon, 0),
#     "IVON-MC8":  (model_ivon, optimizer_ivon, 8)
# }

# %%
def evaluate_probs(model, optimizer, loader, device, test_samples=0):
    """
    test_samples = 0 → IVON@mean        (deterministic mean weights)
    test_samples = 1 → single posterior sample
    test_samples > 1 → MC posterior averaging
    Deterministic optimizers automatically handled.
    """

    model.eval()
    all_probs, all_labels, all_logits = [], [], []
    ivon_mode = hasattr(optimizer, "sampled_params")

    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)

            # ================================================
            # CASE A — IVON@mean (deterministic)
            # ================================================
            if ivon_mode and test_samples == 0:
                logits = model(X)
                probs = F.softmax(logits, dim=1)

            # ================================================
            # CASE B — IVON with posterior sampling
            # ================================================
            elif ivon_mode and test_samples >= 1:

                if test_samples == 1:
                    # single posterior sample
                    with optimizer.sampled_params(train=False):
                        logits = model(X)
                        probs = F.softmax(logits, dim=1)

                else:
                    # MC averaging
                    num_classes = model.fc.out_features if hasattr(model, "fc") else 10
                    mc_probs = torch.zeros(test_samples, X.size(0), num_classes, device=device)

                    for s in range(test_samples):
                        with optimizer.sampled_params(train=False):
                            mc_probs[s] = F.softmax(model(X), dim=1)

                    probs = mc_probs.mean(0)
                    logits = probs.log()  # logits not meaningful under MC, but needed for uniform API

            # ================================================
            # CASE C — Deterministic optimizers (SGD/AdamW/etc.)
            # ================================================
            else:
                logits = model(X)
                probs = F.softmax(logits, dim=1)

            all_probs.append(probs.cpu())
            all_logits.append(logits.cpu())
            all_labels.append(y.cpu())

    return torch.cat(all_probs), torch.cat(all_labels), torch.cat(all_logits)



# =======================================================================

def compute_ece(probs, labels, n_bins=20):
    confidences, preds = probs.max(dim=1)
    correctness = preds.eq(labels)
    bin_boundaries = torch.linspace(0, 1, n_bins + 1)

    ece = 0.0
    for i in range(n_bins):
        low, high = bin_boundaries[i], bin_boundaries[i+1]
        mask = (confidences >= low) & (confidences < high)
        if not mask.any():
            continue

        bin_conf = confidences[mask].mean()
        bin_acc = correctness[mask].float().mean()
        ece += mask.float().mean() * (bin_conf - bin_acc).abs()

    return float(ece)

# =======================================================================

def evaluate_all_metrics(model, optimizer, loader, device, test_samples=0):
    model.eval()

    probs, labels, logits = evaluate_probs(
        model, optimizer, loader, device, test_samples
    )

    # Top-1 accuracy
    top1 = (probs.argmax(1) == labels).float().mean().item()

    # Top-5 accuracy (safe for CIFAR-10 & larger datasets)
    top5 = (
        probs.topk(min(5, probs.size(1)), dim=1).indices
        .eq(labels.unsqueeze(1))
        .any(dim=1)
        .float()
        .mean()
        .item()
    )

    # True NLL (cross-entropy)
    nll = F.cross_entropy(logits, labels, reduction="mean").item()

    # ECE
    ece = compute_ece(probs, labels)

    # Brier score
    one_hot = F.one_hot(labels, probs.size(1)).float()
    brier = ((probs - one_hot) ** 2).mean().item()

    return {
        "Top-1 Acc ↑": top1,
        "Top-5 Acc ↑": top5,
        "NLL ↓": nll,
        "ECE ↓": ece,
        "Brier ↓": brier,
        "probs": probs,
        "labels": labels,
    }
#=========================================================================
def compare_methods(methods_dict, loader, device):
    """
    methods_dict example:
    {
        "IVON@mean": (model_ivon, optimizer_ivon, 0),
        "IVON-MC8":  (model_ivon, optimizer_ivon, 8),
        "SGD":       (model_sgd, optimizer_sgd, 0)
    }
    """

    rows = []

    for name, (model, optimizer, samples) in methods_dict.items():
        print(f"Evaluating {name} (samples={samples})...")

        metrics = evaluate_all_metrics(
            model=model,
            optimizer=optimizer,
            loader=loader,
            device=device,
            test_samples=samples
        )

        rows.append({
            "Method": name,
            "Top-1 Acc ↑": metrics["Top-1 Acc ↑"],
            "Top-5 Acc ↑": metrics["Top-5 Acc ↑"],
            "NLL ↓": metrics["NLL ↓"],
            "ECE ↓": metrics["ECE ↓"],
            "Brier ↓": metrics["Brier ↓"],
        })

    df = pd.DataFrame(rows).set_index("Method")
    print("\n=== Comparison Table ===")
    print(df)
    return df
#====================================================================

def plot_calibration_curve(probs, labels, n_bins=20, label_name="Model"):
    """
    Plots a reliability diagram (calibration curve) for a model.

    probs: tensor (N, C) with predicted probabilities
    labels: tensor (N,)
    """

    # Convert to numpy
    probs_np = probs.numpy()
    labels_np = labels.numpy()

    # Predicted confidence = max probability per sample
    confidences = np.max(probs_np, axis=1)

    # Predicted class
    predictions = np.argmax(probs_np, axis=1)

    # Correctness mask
    correctness = (predictions == labels_np).astype(int)

    # Compute calibration curve (fraction of positives vs confidence)
    frac_pos, mean_conf = calibration_curve(
        correctness,
        confidences,
        n_bins=n_bins,
        strategy='uniform'
    )

    # Plot
    plt.plot(mean_conf, frac_pos, linestyle="-", marker="s", label=label_name)

    plt.plot([0, 1], [0, 1], "--", color="gray")  # perfect calibration
    plt.xlabel("Mean predicted confidence")
    plt.ylabel("Fraction of correct predictions")
    plt.title("Calibration Curve (Reliability Diagram)")
    plt.grid(True)

# %%
def ivon_predict_with_variance_mc(model, ivon_optimizer, X, mc_samples=5, device='cpu'):
    """
    Returns:
      mean_logits: [B, C]  (posterior predictive mean of logits)
      var:         [B]     (predictive variance per example, scalar)
    Uses MC sampling of weights via ivon_optimizer.sampled_params().
    """
    model.eval()
    preds_logits = []

    # If no ivon optimizer provided, we just make a normal prediction
    if ivon_optimizer is None or not hasattr(ivon_optimizer, "sampled_params"):
        with torch.no_grad():
            logits = model(X)
        mean_logits = logits
        var = torch.zeros(X.shape[0], device=device)
        return mean_logits, var

    # Monte Carlo sampling — here we do several predictions with small changes in the weights, compute softmax then variance
    with torch.no_grad():
        for _ in range(mc_samples):
            with ivon_optimizer.sampled_params(train=False):
                logits = model(X)           # [B, C]
                probs = F.softmax(logits, dim=1)  # store probs to get predictive variance in probability space
                preds_logits.append(probs)

        preds = torch.stack(preds_logits, dim=0)   # [S, B, C]
        mean_probs = preds.mean(dim=0)             # [B, C]
        # scalar variance per sample: mean over classes of var over MC
        var_per_class = preds.var(dim=0)           # [B, C]
        var = var_per_class.mean(dim=1)            # [B]

        # For test loss and other uses we often want logits: use inverse-softmax approx by taking log(mean_probs)
        # safer: convert mean_probs -> logits via logit (clamped)
        eps = 1e-12
        mean_probs_clamped = mean_probs.clamp(min=eps, max=1.0 - eps)
        mean_logits = torch.log(mean_probs_clamped)

    return mean_logits.to(device), var.to(device)


# The test losses are used for figure 5.
def evaluate_epoch(model, test_loader, device, ivon_optimizer=None, mc_samples=5):
    """
    Compute:
      - test_loss (mean NLL over dataset)
      - loo_loss
    Uses ivon_predict_with_variance_mc to obtain mean_logits and predictive variance.
    """
    model.eval()
    total_test_loss = 0.0
    loo_losses = []
    N = 0

    with torch.no_grad():
        for X, y in test_loader:
            X = X.to(device)
            y = y.to(device)
            batch_size = X.shape[0]

            if ivon_optimizer is not None:
                logits, var = ivon_predict_with_variance_mc(model, ivon_optimizer, X, mc_samples=mc_samples, device=device)
            else:
                logits = model(X)
                var = torch.zeros(batch_size, device=device)

            # Measure normal test loss, how wrong is the model?
            total_test_loss += F.cross_entropy(logits, y, reduction="sum").item()

            # Convert logits into probabilities with softmax.
            probs = F.softmax(logits, dim=1)

            # The model's mistake direction, we get a vector that tells us
            # how much the model should increase the correct class probability
            # and decrease the wrong ones.
            y_onehot = torch.nn.functional.one_hot(y, num_classes=probs.size(1)).float().to(device)
            errors = (y_onehot - probs)                 # [B, C]

            # Now we scale the correction by how sensitive the model is.
            # var - tells us how much the model would change if we removed this
            # example from training.
            # If a single example really influenced training we adjust the prediction a lot.
            adjusted_logits = logits + var.unsqueeze(1) * errors  # broadcast

            # Here we check how wrong the model becomes with this "pretend change"
            loo_batch = F.cross_entropy(adjusted_logits, y, reduction="mean").item()
            loo_losses.append(loo_batch)

            N += batch_size

    test_loss = total_test_loss / max(1, len(test_loader.dataset))
    loo_loss = float(np.mean(loo_losses)) if len(loo_losses) > 0 else float('nan')

    return test_loss, loo_loss

# %%
# ===========================================
# 1. Mount Google Drive
# ===========================================
from google.colab import drive
drive.mount('/content/drive')

# ===========================================
# 2. Define save directory (where checkpoints will be stored)
# ===========================================
save_dir = "/content/drive/MyDrive/Colab Notebooks/ADL/ivon-main"
# Out:
# Mounted at /content/drive

# %%
# --- Train IVON ---
model_ivon = ResNet20().to(device)

optimizer_ivon = ivon.IVON(model_ivon.parameters(), lr=0.1, ess=len(train_dataset))

# Initialize variances for IVON parameters
for p in model_ivon.parameters():
    if p not in optimizer_ivon.state:
        optimizer_ivon.state[p] = {}
    optimizer_ivon.state[p]["variance"] = torch.full_like(p.data, 1e-4)

train_samples = 1
ivon_stats = {"test_loss": [], "loo_loss": []}

for epoch in range(NUMB_EPOCHS):
    model_ivon.train()
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)

        optimizer_ivon.zero_grad()

        for _ in range(train_samples):
            with optimizer_ivon.sampled_params(train=True):
                logits = model_ivon(X)
                loss = F.cross_entropy(logits, y)
                loss.backward()

        optimizer_ivon.step()

    # Evaluate with variance-aware prediction
    test_loss, loo_loss = evaluate_epoch(
        model_ivon,
        test_loader,
        device,
        ivon_optimizer=optimizer_ivon
    )
    ivon_stats["test_loss"].append(test_loss)
    ivon_stats["loo_loss"].append(loo_loss)

    print(f"IVON Epoch {epoch+1}: test={test_loss:.4f}, loo={loo_loss:.4f}")


##################################################################################
sgd_stats = {"test_loss": [], "loo_loss": []}
def train_sgd(model, optimizer, train_loader, device, epochs=NUMB_EPOCHS):
    model.to(device)

    for epoch in range(epochs):
        model.train()
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X)
            loss = F.cross_entropy(logits, y)
            loss.backward()
            optimizer.step()

        test_loss, loo_loss = evaluate_epoch(model, test_loader, device)
        sgd_stats["test_loss"].append(test_loss)
        sgd_stats["loo_loss"].append(loo_loss)

        print(f"SGD Epoch {epoch+1}: test={test_loss:.4f}, loo={loo_loss:.4f}")


model_sgd = ResNet20().to(device)
optimizer_sgd = torch.optim.SGD(model_sgd.parameters(), lr=0.1)


train_sgd(model_sgd, optimizer_sgd, train_loader, device=device, epochs=NUMB_EPOCHS)
##################################################################################
adam_stats = {"test_loss": [], "loo_loss": []}
def train_adam(model, optimizer, train_loader, device, epochs=10):
    model.to(device)

    for epoch in range(epochs):
        model.train()  # MUST be inside the loop

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X)
            loss = F.cross_entropy(logits, y)
            loss.backward()
            optimizer.step()

        test_loss, loo_loss = evaluate_epoch(model, test_loader, device)
        adam_stats["test_loss"].append(test_loss)
        adam_stats["loo_loss"].append(loo_loss)

        print(f"AdamW Epoch {epoch+1}: test={test_loss:.4f}, loo={loo_loss:.4f}")


model_adam = ResNet20().to(device)
# optimizer_adam = torch.optim.Adam(model_adam.parameters(), lr=0.001)

optimizer_adam = torch.optim.AdamW(
    model_adam.parameters(),
    lr=1e-3,
    weight_decay=5e-4,
    betas=(0.9, 0.999)
)


train_adam(model_adam, optimizer_adam, train_loader, device, epochs=NUMB_EPOCHS)

##################################################################################
import torch

# ===== Save IVON =====
torch.save({
    "model_state_dict": model_ivon.state_dict(),
    "optimizer_state_dict": optimizer_ivon.state_dict(),
}, f"{save_dir}/ivon_checkpoint2.pth")
print("Saved IVON checkpoint!")

# ===== Save SGD =====
torch.save({
    "model_state_dict": model_sgd.state_dict(),
    "optimizer_state_dict": optimizer_sgd.state_dict(),
}, f"{save_dir}/sgd_checkpoint2.pth")
print("Saved SGD checkpoint!")

# ===== Save AdamW =====
torch.save({
    "model_state_dict": model_adam.state_dict(),
    "optimizer_state_dict": optimizer_adam.state_dict(),
}, f"{save_dir}/adam_checkpoint2.pth")
print("Saved Adam checkpoint!")
# Out:
# IVON Epoch 1: test=1.5760, loo=1.5747
# IVON Epoch 2: test=1.0518, loo=1.0511
# IVON Epoch 3: test=0.9172, loo=0.9167
# IVON Epoch 4: test=0.8736, loo=0.8730
# IVON Epoch 5: test=0.6387, loo=0.6382
# IVON Epoch 6: test=0.7161, loo=0.7156
# IVON Epoch 7: test=0.7451, loo=0.7446
# IVON Epoch 8: test=0.5972, loo=0.5968
# IVON Epoch 9: test=0.5354, loo=0.5350
# IVON Epoch 10: test=0.5756, loo=0.5752
# IVON Epoch 11: test=0.5426, loo=0.5422
# IVON Epoch 12: test=0.5466, loo=0.5462
# IVON Epoch 13: test=0.4804, loo=0.4801
# IVON Epoch 14: test=0.5014, loo=0.5011
# IVON Epoch 15: test=0.4581, loo=0.4578
# IVON Epoch 16: test=0.4796, loo=0.4792
# IVON Epoch 17: test=0.4630, loo=0.4627
# IVON Epoch 18: test=0.4784, loo=0.4780
# IVON Epoch 19: test=0.4742, loo=0.4738
# IVON Epoch 20: test=0.4668, loo=0.4664
# IVON Epoch 21: test=0.4315, loo=0.4312
# IVON Epoch 22: test=0.4683, loo=0.4680
# IVON Epoch 23: test=0.4329, loo=0.4326
# IVON Epoch 24: test=0.4852, loo=0.4849
# IVON Epoch 25: test=0.4664, loo=0.4660
# IVON Epoch 26: test=0.4403, loo=0.4400
# IVON Epoch 27: test=0.4335, loo=0.4331
# IVON Epoch 28: test=0.4433, loo=0.4430
# IVON Epoch 29: test=0.4415, loo=0.4412
# IVON Epoch 30: test=0.4201, loo=0.4198
# IVON Epoch 31: test=0.4156, loo=0.4153
# IVON Epoch 32: test=0.4056, loo=0.4053
# IVON Epoch 33: test=0.3915, loo=0.3912
# IVON Epoch 34: test=0.4438, loo=0.4435
# IVON Epoch 35: test=0.4283, loo=0.4279
# IVON Epoch 36: test=0.4293, loo=0.4290
# IVON Epoch 37: test=0.4536, loo=0.4532
# IVON Epoch 38: test=0.3829, loo=0.3826
# IVON Epoch 39: test=0.4044, loo=0.4040
# IVON Epoch 40: test=0.4089, loo=0.4085
# IVON Epoch 41: test=0.4120, loo=0.4117
# IVON Epoch 42: test=0.4765, loo=0.4761
# IVON Epoch 43: test=0.4209, loo=0.4205
# IVON Epoch 44: test=0.3932, loo=0.3928
# IVON Epoch 45: test=0.4334, loo=0.4329
# IVON Epoch 46: test=0.4077, loo=0.4074
# IVON Epoch 47: test=0.4214, loo=0.4210
# IVON Epoch 48: test=0.4052, loo=0.4048
# IVON Epoch 49: test=0.4021, loo=0.4017
# IVON Epoch 50: test=0.4164, loo=0.4160
# IVON Epoch 51: test=0.4030, loo=0.4026
# IVON Epoch 52: test=0.4324, loo=0.4320
# IVON Epoch 53: test=0.4310, loo=0.4306
# IVON Epoch 54: test=0.3968, loo=0.3964
# IVON Epoch 55: test=0.3940, loo=0.3936
# IVON Epoch 56: test=0.4285, loo=0.4282
# IVON Epoch 57: test=0.4114, loo=0.4110
# IVON Epoch 58: test=0.4197, loo=0.4193
# IVON Epoch 59: test=0.4285, loo=0.4281
# IVON Epoch 60: test=0.4090, loo=0.4086
# IVON Epoch 61: test=0.4446, loo=0.4441
# IVON Epoch 62: test=0.4473, loo=0.4468
# IVON Epoch 63: test=0.4117, loo=0.4113
# IVON Epoch 64: test=0.4418, loo=0.4413
# IVON Epoch 65: test=0.4994, loo=0.4990
# IVON Epoch 66: test=0.3909, loo=0.3905
# IVON Epoch 67: test=0.4557, loo=0.4552
# IVON Epoch 68: test=0.4189, loo=0.4185
# IVON Epoch 69: test=0.3907, loo=0.3903
# IVON Epoch 70: test=0.4250, loo=0.4245
# IVON Epoch 71: test=0.3993, loo=0.3989
# IVON Epoch 72: test=0.4176, loo=0.4172
# IVON Epoch 73: test=0.4350, loo=0.4345
# IVON Epoch 74: test=0.4047, loo=0.4043
# IVON Epoch 75: test=0.3857, loo=0.3853
# IVON Epoch 76: test=0.4883, loo=0.4878
# IVON Epoch 77: test=0.4412, loo=0.4407
# IVON Epoch 78: test=0.4153, loo=0.4150
# IVON Epoch 79: test=0.3794, loo=0.3789
# IVON Epoch 80: test=0.4067, loo=0.4063
# IVON Epoch 81: test=0.4817, loo=0.4812
# IVON Epoch 82: test=0.4217, loo=0.4213
# IVON Epoch 83: test=0.4118, loo=0.4113
# IVON Epoch 84: test=0.3906, loo=0.3902
# IVON Epoch 85: test=0.4283, loo=0.4279
# IVON Epoch 86: test=0.4332, loo=0.4328
# IVON Epoch 87: test=0.3895, loo=0.3890
# IVON Epoch 88: test=0.4660, loo=0.4655
# IVON Epoch 89: test=0.4415, loo=0.4411
# IVON Epoch 90: test=0.4153, loo=0.4149
# IVON Epoch 91: test=0.4116, loo=0.4111
# IVON Epoch 92: test=0.3924, loo=0.3920
# IVON Epoch 93: test=0.4476, loo=0.4472
# IVON Epoch 94: test=0.4035, loo=0.4031
# IVON Epoch 95: test=0.4058, loo=0.4053
# IVON Epoch 96: test=0.5292, loo=0.5287
# IVON Epoch 97: test=0.3895, loo=0.3891
# IVON Epoch 98: test=0.4233, loo=0.4229
# IVON Epoch 99: test=0.3823, loo=0.3819
# IVON Epoch 100: test=0.4424, loo=0.4419
# IVON Epoch 101: test=0.4124, loo=0.4119
# IVON Epoch 102: test=0.3791, loo=0.3787
# IVON Epoch 103: test=0.4130, loo=0.4125
# IVON Epoch 104: test=0.4099, loo=0.4095
# IVON Epoch 105: test=0.3955, loo=0.3951
# IVON Epoch 106: test=0.4616, loo=0.4611
# IVON Epoch 107: test=0.3829, loo=0.3825
# IVON Epoch 108: test=0.4320, loo=0.4315
# IVON Epoch 109: test=0.4183, loo=0.4178
# IVON Epoch 110: test=0.4270, loo=0.4265
# IVON Epoch 111: test=0.4494, loo=0.4489
# IVON Epoch 112: test=0.4350, loo=0.4345
# IVON Epoch 113: test=0.3899, loo=0.3894
# IVON Epoch 114: test=0.4328, loo=0.4324
# IVON Epoch 115: test=0.3991, loo=0.3987
# IVON Epoch 116: test=0.3952, loo=0.3947
# IVON Epoch 117: test=0.4328, loo=0.4323
# IVON Epoch 118: test=0.4091, loo=0.4086
# IVON Epoch 119: test=0.4953, loo=0.4948
# IVON Epoch 120: test=0.3983, loo=0.3979
# IVON Epoch 121: test=0.4106, loo=0.4101
# IVON Epoch 122: test=0.4688, loo=0.4682
# IVON Epoch 123: test=0.4484, loo=0.4479
# IVON Epoch 124: test=0.4253, loo=0.4248
# IVON Epoch 125: test=0.4013, loo=0.4009
# IVON Epoch 126: test=0.3853, loo=0.3849
# IVON Epoch 127: test=0.4002, loo=0.3997
# IVON Epoch 128: test=0.4027, loo=0.4022
# IVON Epoch 129: test=0.3907, loo=0.3903
# IVON Epoch 130: test=0.3755, loo=0.3750
# IVON Epoch 131: test=0.3959, loo=0.3955
# IVON Epoch 132: test=0.4420, loo=0.4415
# IVON Epoch 133: test=0.4097, loo=0.4093
# IVON Epoch 134: test=0.4096, loo=0.4091
# IVON Epoch 135: test=0.3649, loo=0.3644
# IVON Epoch 136: test=0.4218, loo=0.4213
# IVON Epoch 137: test=0.4542, loo=0.4537
# IVON Epoch 138: test=0.4667, loo=0.4661
# IVON Epoch 139: test=0.4355, loo=0.4350
# IVON Epoch 140: test=0.3702, loo=0.3698
# IVON Epoch 141: test=0.3691, loo=0.3687
# IVON Epoch 142: test=0.4582, loo=0.4576
# IVON Epoch 143: test=0.4434, loo=0.4429
# IVON Epoch 144: test=0.4860, loo=0.4854
# IVON Epoch 145: test=0.3575, loo=0.3571
# IVON Epoch 146: test=0.3965, loo=0.3960
# IVON Epoch 147: test=0.3818, loo=0.3813
# IVON Epoch 148: test=0.4339, loo=0.4334
# IVON Epoch 149: test=0.4212, loo=0.4206
# IVON Epoch 150: test=0.4121, loo=0.4116
# SGD Epoch 1: test=1.2660, loo=1.2660
# SGD Epoch 2: test=1.0161, loo=1.0161
# SGD Epoch 3: test=0.8180, loo=0.8180
# SGD Epoch 4: test=0.8794, loo=0.8794
# SGD Epoch 5: test=1.2078, loo=1.2078
# SGD Epoch 6: test=0.6872, loo=0.6872
# SGD Epoch 7: test=0.7099, loo=0.7099
# SGD Epoch 8: test=0.7530, loo=0.7530
# SGD Epoch 9: test=0.6276, loo=0.6276
# SGD Epoch 10: test=0.5629, loo=0.5629
# SGD Epoch 11: test=0.6016, loo=0.6016
# SGD Epoch 12: test=0.5798, loo=0.5798
# SGD Epoch 13: test=0.4980, loo=0.4980
# SGD Epoch 14: test=0.4885, loo=0.4885
# SGD Epoch 15: test=0.4964, loo=0.4964
# SGD Epoch 16: test=0.5421, loo=0.5421
# SGD Epoch 17: test=0.4883, loo=0.4883
# SGD Epoch 18: test=0.4838, loo=0.4838
# SGD Epoch 19: test=0.4512, loo=0.4512
# SGD Epoch 20: test=0.4657, loo=0.4657
# SGD Epoch 21: test=0.4653, loo=0.4653
# SGD Epoch 22: test=0.5202, loo=0.5202
# SGD Epoch 23: test=0.4706, loo=0.4706
# SGD Epoch 24: test=0.4351, loo=0.4351
# SGD Epoch 25: test=0.4377, loo=0.4377
# SGD Epoch 26: test=0.4650, loo=0.4650
# SGD Epoch 27: test=0.5141, loo=0.5141
# SGD Epoch 28: test=0.4790, loo=0.4790
# SGD Epoch 29: test=0.4221, loo=0.4221
# SGD Epoch 30: test=0.4560, loo=0.4560
# SGD Epoch 31: test=0.4104, loo=0.4104
# SGD Epoch 32: test=0.4227, loo=0.4227
# SGD Epoch 33: test=0.6291, loo=0.6291
# SGD Epoch 34: test=0.4581, loo=0.4581
# SGD Epoch 35: test=0.4208, loo=0.4208
# SGD Epoch 36: test=0.4455, loo=0.4455
# SGD Epoch 37: test=0.4017, loo=0.4017
# SGD Epoch 38: test=0.4700, loo=0.4700
# SGD Epoch 39: test=0.4587, loo=0.4587
# SGD Epoch 40: test=0.4858, loo=0.4858
# SGD Epoch 41: test=0.4528, loo=0.4528
# SGD Epoch 42: test=0.4304, loo=0.4304
# SGD Epoch 43: test=0.5268, loo=0.5268
# SGD Epoch 44: test=0.4331, loo=0.4331
# SGD Epoch 45: test=0.4190, loo=0.4190
# SGD Epoch 46: test=0.4118, loo=0.4118
# SGD Epoch 47: test=0.4552, loo=0.4552
# SGD Epoch 48: test=0.4177, loo=0.4177
# SGD Epoch 49: test=0.4627, loo=0.4627
# SGD Epoch 50: test=0.4517, loo=0.4517
# SGD Epoch 51: test=0.4356, loo=0.4356
# SGD Epoch 52: test=0.4631, loo=0.4631
# SGD Epoch 53: test=0.4284, loo=0.4284
# SGD Epoch 54: test=0.4265, loo=0.4265
# SGD Epoch 55: test=0.4447, loo=0.4447
# SGD Epoch 56: test=0.4238, loo=0.4238
# SGD Epoch 57: test=0.4762, loo=0.4762
# SGD Epoch 58: test=0.4512, loo=0.4512
# SGD Epoch 59: test=0.4408, loo=0.4408
# SGD Epoch 60: test=0.4361, loo=0.4361
# SGD Epoch 61: test=0.4977, loo=0.4977
# SGD Epoch 62: test=0.4629, loo=0.4629
# SGD Epoch 63: test=0.4461, loo=0.4461
# SGD Epoch 64: test=0.4586, loo=0.4586
# SGD Epoch 65: test=0.4384, loo=0.4384
# SGD Epoch 66: test=0.4401, loo=0.4401
# SGD Epoch 67: test=0.5302, loo=0.5302
# SGD Epoch 68: test=0.4785, loo=0.4785
# SGD Epoch 69: test=0.4658, loo=0.4658
# SGD Epoch 70: test=0.4809, loo=0.4809
# SGD Epoch 71: test=0.4546, loo=0.4546
# SGD Epoch 72: test=0.5081, loo=0.5081
# SGD Epoch 73: test=0.4534, loo=0.4534
# SGD Epoch 74: test=0.5302, loo=0.5302
# SGD Epoch 75: test=0.4396, loo=0.4396
# SGD Epoch 76: test=0.4631, loo=0.4631
# SGD Epoch 77: test=0.4953, loo=0.4953
# SGD Epoch 78: test=0.4686, loo=0.4686
# SGD Epoch 79: test=0.4634, loo=0.4634
# SGD Epoch 80: test=0.4873, loo=0.4873
# SGD Epoch 81: test=0.4882, loo=0.4882
# SGD Epoch 82: test=0.5045, loo=0.5045
# SGD Epoch 83: test=0.5044, loo=0.5044
# SGD Epoch 84: test=0.4815, loo=0.4815
# SGD Epoch 85: test=0.4769, loo=0.4769
# SGD Epoch 86: test=0.4809, loo=0.4809
# SGD Epoch 87: test=0.4862, loo=0.4862
# SGD Epoch 88: test=0.4633, loo=0.4633
# SGD Epoch 89: test=0.5121, loo=0.5121
# SGD Epoch 90: test=0.4800, loo=0.4800
# SGD Epoch 91: test=0.4834, loo=0.4834
# SGD Epoch 92: test=0.4975, loo=0.4975
# SGD Epoch 93: test=0.4918, loo=0.4918
# SGD Epoch 94: test=0.4950, loo=0.4950
# SGD Epoch 95: test=0.4620, loo=0.4620
# SGD Epoch 96: test=0.5073, loo=0.5073
# SGD Epoch 97: test=0.4941, loo=0.4941
# SGD Epoch 98: test=0.5228, loo=0.5228
# SGD Epoch 99: test=0.4951, loo=0.4951
# SGD Epoch 100: test=0.4803, loo=0.4803
# SGD Epoch 101: test=0.5151, loo=0.5151
# SGD Epoch 102: test=0.5222, loo=0.5222
# SGD Epoch 103: test=0.5134, loo=0.5134
# SGD Epoch 104: test=0.4708, loo=0.4708
# SGD Epoch 105: test=0.5282, loo=0.5282
# SGD Epoch 106: test=0.5303, loo=0.5303
# SGD Epoch 107: test=0.5041, loo=0.5041
# SGD Epoch 108: test=0.5248, loo=0.5248
# SGD Epoch 109: test=0.5844, loo=0.5844
# SGD Epoch 110: test=0.4978, loo=0.4978
# SGD Epoch 111: test=0.5215, loo=0.5215
# SGD Epoch 112: test=0.5234, loo=0.5234
# SGD Epoch 113: test=0.5401, loo=0.5401
# SGD Epoch 114: test=0.5073, loo=0.5073
# SGD Epoch 115: test=0.5172, loo=0.5172
# SGD Epoch 116: test=0.5069, loo=0.5069
# SGD Epoch 117: test=0.5326, loo=0.5326
# SGD Epoch 118: test=0.5320, loo=0.5320
# SGD Epoch 119: test=0.5091, loo=0.5091
# SGD Epoch 120: test=0.5214, loo=0.5214
# SGD Epoch 121: test=0.4958, loo=0.4958
# SGD Epoch 122: test=0.5150, loo=0.5150
# SGD Epoch 123: test=0.5365, loo=0.5365
# SGD Epoch 124: test=0.5373, loo=0.5373
# SGD Epoch 125: test=0.5351, loo=0.5351
# SGD Epoch 126: test=0.5082, loo=0.5082
# SGD Epoch 127: test=0.4975, loo=0.4975
# SGD Epoch 128: test=0.5416, loo=0.5416
# SGD Epoch 129: test=0.5398, loo=0.5398
# SGD Epoch 130: test=0.5034, loo=0.5034
# SGD Epoch 131: test=0.5331, loo=0.5331
# SGD Epoch 132: test=0.5294, loo=0.5294
# SGD Epoch 133: test=0.5591, loo=0.5591
# SGD Epoch 134: test=0.6379, loo=0.6379
# SGD Epoch 135: test=0.5576, loo=0.5576
# SGD Epoch 136: test=0.5285, loo=0.5285
# SGD Epoch 137: test=0.5144, loo=0.5144
# SGD Epoch 138: test=0.5299, loo=0.5299
# SGD Epoch 139: test=0.5403, loo=0.5403
# SGD Epoch 140: test=0.5615, loo=0.5615
# SGD Epoch 141: test=0.5418, loo=0.5418
# SGD Epoch 142: test=0.5451, loo=0.5451
# SGD Epoch 143: test=0.5116, loo=0.5116
# SGD Epoch 144: test=0.5133, loo=0.5133
# SGD Epoch 145: test=0.5451, loo=0.5451
# SGD Epoch 146: test=0.5557, loo=0.5557
# SGD Epoch 147: test=0.5266, loo=0.5266
# SGD Epoch 148: test=0.5238, loo=0.5238
# SGD Epoch 149: test=0.5158, loo=0.5158
# SGD Epoch 150: test=0.5713, loo=0.5713
# AdamW Epoch 1: test=1.4868, loo=1.4868
# AdamW Epoch 2: test=0.9851, loo=0.9851
# AdamW Epoch 3: test=0.8249, loo=0.8249
# AdamW Epoch 4: test=0.8098, loo=0.8098
# AdamW Epoch 5: test=0.7115, loo=0.7115
# AdamW Epoch 6: test=0.6253, loo=0.6253
# AdamW Epoch 7: test=0.6057, loo=0.6057
# AdamW Epoch 8: test=0.6521, loo=0.6521
# AdamW Epoch 9: test=0.6126, loo=0.6126
# AdamW Epoch 10: test=0.5396, loo=0.5396
# AdamW Epoch 11: test=0.5329, loo=0.5329
# AdamW Epoch 12: test=0.5374, loo=0.5374
# AdamW Epoch 13: test=0.5111, loo=0.5111
# AdamW Epoch 14: test=0.4894, loo=0.4894
# AdamW Epoch 15: test=0.4964, loo=0.4964
# AdamW Epoch 16: test=0.5019, loo=0.5019
# AdamW Epoch 17: test=0.4585, loo=0.4585
# AdamW Epoch 18: test=0.4370, loo=0.4370
# AdamW Epoch 19: test=0.4693, loo=0.4693
# AdamW Epoch 20: test=0.4540, loo=0.4540
# AdamW Epoch 21: test=0.4487, loo=0.4487
# AdamW Epoch 22: test=0.4622, loo=0.4622
# AdamW Epoch 23: test=0.4373, loo=0.4373
# AdamW Epoch 24: test=0.4530, loo=0.4530
# AdamW Epoch 25: test=0.4543, loo=0.4543
# AdamW Epoch 26: test=0.4389, loo=0.4389
# AdamW Epoch 27: test=0.4286, loo=0.4286
# AdamW Epoch 28: test=0.4363, loo=0.4363
# AdamW Epoch 29: test=0.4427, loo=0.4427
# AdamW Epoch 30: test=0.4177, loo=0.4177
# AdamW Epoch 31: test=0.4103, loo=0.4103
# AdamW Epoch 32: test=0.3971, loo=0.3971
# AdamW Epoch 33: test=0.4008, loo=0.4008
# AdamW Epoch 34: test=0.4393, loo=0.4393
# AdamW Epoch 35: test=0.4244, loo=0.4244
# AdamW Epoch 36: test=0.4068, loo=0.4068
# AdamW Epoch 37: test=0.4438, loo=0.4438
# AdamW Epoch 38: test=0.3966, loo=0.3966
# AdamW Epoch 39: test=0.3866, loo=0.3866
# AdamW Epoch 40: test=0.4096, loo=0.4096
# AdamW Epoch 41: test=0.4242, loo=0.4242
# AdamW Epoch 42: test=0.3908, loo=0.3908
# AdamW Epoch 43: test=0.4060, loo=0.4060
# AdamW Epoch 44: test=0.4530, loo=0.4530
# AdamW Epoch 45: test=0.4221, loo=0.4221
# AdamW Epoch 46: test=0.3937, loo=0.3937
# AdamW Epoch 47: test=0.4025, loo=0.4025
# AdamW Epoch 48: test=0.4107, loo=0.4107
# AdamW Epoch 49: test=0.4156, loo=0.4156
# AdamW Epoch 50: test=0.4018, loo=0.4018
# AdamW Epoch 51: test=0.4276, loo=0.4276
# AdamW Epoch 52: test=0.4539, loo=0.4539
# AdamW Epoch 53: test=0.4628, loo=0.4628
# AdamW Epoch 54: test=0.4098, loo=0.4098
# AdamW Epoch 55: test=0.4026, loo=0.4026
# AdamW Epoch 56: test=0.4119, loo=0.4119
# AdamW Epoch 57: test=0.4200, loo=0.4200
# AdamW Epoch 58: test=0.4219, loo=0.4219
# AdamW Epoch 59: test=0.4689, loo=0.4689
# AdamW Epoch 60: test=0.4126, loo=0.4126
# AdamW Epoch 61: test=0.4227, loo=0.4227
# AdamW Epoch 62: test=0.4264, loo=0.4264
# AdamW Epoch 63: test=0.4215, loo=0.4215
# AdamW Epoch 64: test=0.4076, loo=0.4076
# AdamW Epoch 65: test=0.4401, loo=0.4401
# AdamW Epoch 66: test=0.4495, loo=0.4495
# AdamW Epoch 67: test=0.4159, loo=0.4159
# AdamW Epoch 68: test=0.4298, loo=0.4298
# AdamW Epoch 69: test=0.4511, loo=0.4511
# AdamW Epoch 70: test=0.4108, loo=0.4108
# AdamW Epoch 71: test=0.4252, loo=0.4252
# AdamW Epoch 72: test=0.4339, loo=0.4339
# AdamW Epoch 73: test=0.4673, loo=0.4673
# AdamW Epoch 74: test=0.4346, loo=0.4346
# AdamW Epoch 75: test=0.4424, loo=0.4424
# AdamW Epoch 76: test=0.4722, loo=0.4722
# AdamW Epoch 77: test=0.4427, loo=0.4427
# AdamW Epoch 78: test=0.4707, loo=0.4707
# AdamW Epoch 79: test=0.4405, loo=0.4405
# AdamW Epoch 80: test=0.4394, loo=0.4394
# AdamW Epoch 81: test=0.4578, loo=0.4578
# AdamW Epoch 82: test=0.5293, loo=0.5293
# AdamW Epoch 83: test=0.4433, loo=0.4433
# AdamW Epoch 84: test=0.4334, loo=0.4334
# AdamW Epoch 85: test=0.4583, loo=0.4583
# AdamW Epoch 86: test=0.4543, loo=0.4543
# AdamW Epoch 87: test=0.4858, loo=0.4858
# AdamW Epoch 88: test=0.4767, loo=0.4767
# AdamW Epoch 89: test=0.4327, loo=0.4327
# AdamW Epoch 90: test=0.4882, loo=0.4882
# AdamW Epoch 91: test=0.4751, loo=0.4751
# AdamW Epoch 92: test=0.4498, loo=0.4498
# AdamW Epoch 93: test=0.4396, loo=0.4396
# AdamW Epoch 94: test=0.4675, loo=0.4675
# AdamW Epoch 95: test=0.4470, loo=0.4470
# AdamW Epoch 96: test=0.4762, loo=0.4762
# AdamW Epoch 97: test=0.4718, loo=0.4718
# AdamW Epoch 98: test=0.4726, loo=0.4726
# AdamW Epoch 99: test=0.4837, loo=0.4837
# AdamW Epoch 100: test=0.4797, loo=0.4797
# AdamW Epoch 101: test=0.4776, loo=0.4776
# AdamW Epoch 102: test=0.4820, loo=0.4820
# AdamW Epoch 103: test=0.4728, loo=0.4728
# AdamW Epoch 104: test=0.4706, loo=0.4706
# AdamW Epoch 105: test=0.4880, loo=0.4880
# AdamW Epoch 106: test=0.4917, loo=0.4917
# AdamW Epoch 107: test=0.4957, loo=0.4957
# AdamW Epoch 108: test=0.4548, loo=0.4548
# AdamW Epoch 109: test=0.4662, loo=0.4662
# AdamW Epoch 110: test=0.4808, loo=0.4808
# AdamW Epoch 111: test=0.4795, loo=0.4795
# AdamW Epoch 112: test=0.4614, loo=0.4614
# AdamW Epoch 113: test=0.4640, loo=0.4640
# AdamW Epoch 114: test=0.5184, loo=0.5184
# AdamW Epoch 115: test=0.4734, loo=0.4734
# AdamW Epoch 116: test=0.5083, loo=0.5083
# AdamW Epoch 117: test=0.4960, loo=0.4960
# AdamW Epoch 118: test=0.4928, loo=0.4928
# AdamW Epoch 119: test=0.4930, loo=0.4930
# AdamW Epoch 120: test=0.5347, loo=0.5347
# AdamW Epoch 121: test=0.4911, loo=0.4911
# AdamW Epoch 122: test=0.4998, loo=0.4998
# AdamW Epoch 123: test=0.5245, loo=0.5245
# AdamW Epoch 124: test=0.4938, loo=0.4938
# AdamW Epoch 125: test=0.5075, loo=0.5075
# AdamW Epoch 126: test=0.5176, loo=0.5176
# AdamW Epoch 127: test=0.4974, loo=0.4974
# AdamW Epoch 128: test=0.4859, loo=0.4859
# AdamW Epoch 129: test=0.4913, loo=0.4913
# AdamW Epoch 130: test=0.5259, loo=0.5259
# AdamW Epoch 131: test=0.5158, loo=0.5158
# AdamW Epoch 132: test=0.5253, loo=0.5253
# AdamW Epoch 133: test=0.4827, loo=0.4827
# AdamW Epoch 134: test=0.5809, loo=0.5809
# AdamW Epoch 135: test=0.5183, loo=0.5183
# AdamW Epoch 136: test=0.5294, loo=0.5294
# AdamW Epoch 137: test=0.4922, loo=0.4922
# AdamW Epoch 138: test=0.4880, loo=0.4880
# AdamW Epoch 139: test=0.5324, loo=0.5324
# AdamW Epoch 140: test=0.5285, loo=0.5285
# AdamW Epoch 141: test=0.4964, loo=0.4964
# AdamW Epoch 142: test=0.5178, loo=0.5178
# AdamW Epoch 143: test=0.5307, loo=0.5307
# AdamW Epoch 144: test=0.5034, loo=0.5034
# AdamW Epoch 145: test=0.5087, loo=0.5087
# AdamW Epoch 146: test=0.4994, loo=0.4994
# AdamW Epoch 147: test=0.5401, loo=0.5401
# AdamW Epoch 148: test=0.5357, loo=0.5357
# AdamW Epoch 149: test=0.5398, loo=0.5398
# AdamW Epoch 150: test=0.5187, loo=0.5187
# Saved IVON checkpoint!
# Saved SGD checkpoint!
# Saved Adam checkpoint!

# %%
# ===========================================
# 1. Mount Google Drive
# ===========================================
from google.colab import drive
drive.mount('/content/drive')

import torch
import torch.nn.functional as F

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device:", device)

# ===========================================
# 2. Define save directory
# ===========================================
save_dir = "/content/drive/MyDrive/Colab Notebooks/ADL/ivon-main"

# Optional: list contents
import os
print("Files in save_dir:", os.listdir(save_dir))

# ===========================================
# 3. Rebuild model architecture
# Make sure ResNet20() is already defined in your notebook.
# ===========================================
model_ivon = ResNet20().to(device)
model_sgd = ResNet20().to(device)
model_adam = ResNet20().to(device)

# ===========================================
# 4. Rebuild optimizers exactly as during training
# ===========================================
# IVON optimizer
optimizer_ivon = ivon.IVON(
    model_ivon.parameters(),
    lr=0.1,
    ess=len(train_dataset)
)

# SGD optimizer
optimizer_sgd = torch.optim.SGD(
    model_sgd.parameters(),
    lr=0.1
)

# AdamW optimizer
optimizer_adam = torch.optim.AdamW(
    model_adam.parameters(),
    lr=1e-3,
    weight_decay=5e-4,
    betas=(0.9, 0.999)
)

# ===========================================
# 5. Load checkpoints
# ===========================================
# ----- IVON -----
ckpt = torch.load(f"{save_dir}/ivon_checkpoint2.pth", map_location=device)
model_ivon.load_state_dict(ckpt["model_state_dict"])
optimizer_ivon.load_state_dict(ckpt["optimizer_state_dict"])
print("Loaded IVON checkpoint")

# ----- SGD -----
ckpt = torch.load(f"{save_dir}/sgd_checkpoint2.pth", map_location=device)
model_sgd.load_state_dict(ckpt["model_state_dict"])
optimizer_sgd.load_state_dict(ckpt["optimizer_state_dict"])
print("Loaded SGD checkpoint")

# ----- AdamW -----
ckpt = torch.load(f"{save_dir}/adam_checkpoint2.pth", map_location=device)
model_adam.load_state_dict(ckpt["model_state_dict"])
optimizer_adam.load_state_dict(ckpt["optimizer_state_dict"])
print("Loaded AdamW checkpoint")

print("\n=== All models successfully loaded! ===")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using device: cuda
# Files in save_dir: ['ID&OOD_uncertainty_eval_1.ipynb', '.gitignore', 'setup.py', 'LICENSE', 'ivon', 'logistic.ipynb', 'ivon_excluded_model.pth', 'sgd_excluded_model.pth', 'IVONrep.ipynb', 'ivon_checkpoint.pth', 'sgd_checkpoint.pth', 'adam_checkpoint.pth', 'MAP_vs_IVON', 'ID&OOD_uncertainty_eval2.ipynb', 'ivon_checkpoint8.pth', 'ID&OOD_uncertainty_eval.ipynb', 'ivon_checkpoint2.pth', 'sgd_checkpoint2.pth', 'adam_checkpoint2.pth']
# Loaded IVON checkpoint
# Loaded SGD checkpoint
# Loaded AdamW checkpoint
#
# === All models successfully loaded! ===

# %%
# --- Unified evaluation: SGD vs Adam vs IVON@mean vs IVON posterior-average ---

print("\nRunning unified evaluation...\n")

methods = {
    "SGD":        (model_sgd,  optimizer_sgd,      0),   # deterministic
    "Adam":       (model_adam, optimizer_adam,     0),   # deterministic
    "IVON@mean":  (model_ivon, optimizer_ivon,     0),   # ZERO sampling → mean weights
    "IVON-MC8":   (model_ivon, optimizer_ivon,     8),   # 8 posterior samples
}

df_results = compare_methods(methods, test_loader, device)

# --- Plot calibration curves ---
plt.figure(figsize=(7,7))

for name, (model_m, optim_m, test_samples) in methods.items():
    print(f"Plotting calibration curve for {name} ...")
    probs, labels, _ = evaluate_probs(model_m, optim_m, test_loader, device, test_samples)
    plot_calibration_curve(probs, labels, n_bins=20, label_name=name)

plt.title("Calibration Curves — SGD vs Adam vs IVON")
plt.legend()
plt.grid(True)
plt.tight_layout()                           # <-- place before save
plt.savefig("calibration_curves.pdf", bbox_inches="tight")    # <-- save before show
plt.show()                                    # <-- show last
# Out:
# Running unified evaluation...
#
# Evaluating SGD (samples=0)...
# Evaluating Adam (samples=0)...
# Evaluating IVON@mean (samples=0)...
# Evaluating IVON-MC8 (samples=8)...
#
# === Comparison Table ===
#            Top-1 Acc ↑  Top-5 Acc ↑     NLL ↓     ECE ↓   Brier ↓
# Method
# SGD             0.8879       0.9954  0.571256  0.076097  0.018664
# Adam            0.8891       0.9956  0.518723  0.074461  0.018092
# IVON@mean       0.8746       0.9947  0.420263  0.043679  0.018836
# IVON-MC8        0.8747       0.9951  0.411150  0.035652  0.018725
# Plotting calibration curve for SGD ...
# Plotting calibration curve for Adam ...
# Plotting calibration curve for IVON@mean ...
# Plotting calibration curve for IVON-MC8 ...

# %% [markdown]
# ## Understanding `train_samples` and `test_samples` in IVON
#
# Having understood the implementation details in the previous cells of the notebook, we now turn to clarify the conceptual distinction between the two sampling parameters, **`train_samples`** and **`test_samples`**, which appear in the code. Both originate from the same variational Bayesian principle but play distinct roles in the learning and inference stages. During training, the optimizer minimizes
#
# $$
# {L}(q) = \lambda\, \mathbb{E}_{q_{\eta}(\theta)}[\bar{\ell}(\theta)] + D_{\mathrm{KL}}(q_{\eta}(\theta)\,\|\,p(\theta)),
# $$
#
# where $q_{\eta}(\theta)$ is the approximate posterior over network weights. Because the expectation over $q_{\eta}(\theta)$ is intractable, it is replaced by a Monte Carlo estimate obtained through a finite number of **train-time samples**:
#
# $$
# \nabla_{\eta}{L}(q) \approx \frac{1}{S_{\text{train}}} \sum_{s=1}^{S_{\text{train}}} \nabla_{\eta}\ell(\theta^{(s)}),
# \quad \theta^{(s)} \sim q_{\eta}(\theta).
# $$
#
# Each sampled parameter vector $\theta^{(s)}$ represents a stochastic realization of the model’s weights used to compute the loss gradient, thereby injecting uncertainty directly into the optimization process. The parameter `train_samples` thus determines how many such draws are taken per minibatch, balancing computational cost against the variance of the gradient estimate.
#
# At evaluation time, the same variational posterior $q_{\eta}(\theta)$ is employed to form predictions that integrate over parameter uncertainty. Since the predictive distribution
#
# $$
# p(y \mid x) = \int p(y \mid x, \theta)\, q_{\eta}(\theta)\, d\theta
# $$
#
# is also analytically intractable, it is approximated via Monte Carlo averaging over **test-time samples**:
#
# $$
# p(y \mid x) \approx \frac{1}{S_{\text{test}}} \sum_{s=1}^{S_{\text{test}}} p(y \mid x, \theta^{(s)}),
# \quad \theta^{(s)} \sim q_{\eta}(\theta).
# $$
#
# Here, `test_samples` specifies the number of posterior weight realizations used to average predictions, determining the accuracy of the Bayesian model average approximation. Increasing `test_samples` improves calibration and negative log-likelihood but incurs greater inference cost. As demonstrated in the subsequent code reproducing **Figure 4** of the original paper, varying these two sampling parameters—during both training and testing—reveals their complementary influence on model accuracy and uncertainty, illustrating how IVON leverages stochasticity across both phases to achieve well-calibrated predictive performance.

# %%
# ==============================================================
# Reproduce Figure 4 from the IVON paper:
# Effect of Monte Carlo samples during inference
# and training on Accuracy and NLL.
# ==============================================================

# --------------------------------------------------------------
# 1. Train IVON with different train_samples values
# --------------------------------------------------------------
def train_ivon(train_samples=1, epochs=NUMB_EPOCHS):
    model = ResNet20().to(device)
    optimizer = ivon.IVON(model.parameters(), lr=0.1, ess=len(train_dataset))

    for epoch in range(epochs):
        model.train()
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            optimizer.zero_grad()
            for _ in range(train_samples):
                with optimizer.sampled_params(train=True):
                    logits = model(X)
                    loss = F.cross_entropy(logits, y)
                    loss.backward()
            optimizer.step()
    return model, optimizer


# --------------------------------------------------------------
# 2. Evaluate Accuracy and NLL for different test_samples values
# --------------------------------------------------------------
def evaluate_metric_sweep(model, optimizer, test_loader, test_samples_list):
    accs, nlls = [], []

    ivon_mode = hasattr(optimizer, "sampled_params")

    for t in test_samples_list:

        # --- IMPORTANT ---
        # Only IVON supports test_samples > 0
        # SGD / AdamW MUST always use test_samples = 0
        if not ivon_mode:
            t = 0  # force deterministic behavior

        metrics = evaluate_all_metrics(model, optimizer, test_loader, device, test_samples=t)
        accs.append(metrics["Top-1 Acc ↑"])
        nlls.append(metrics["NLL ↓"])

    return accs, nlls

# %%
# # --------------------------------------------------------------
# # 3. Figure 4 — Top row: Varying test_samples
# # --------------------------------------------------------------

test_samples_list = [1, 2, 4, 8, 16, 32]
accs_test, nlls_test = evaluate_metric_sweep(model_ivon, optimizer_ivon, test_loader, test_samples_list)

df_test = pd.DataFrame({
    "Test Samples (MC)": test_samples_list,
    "Accuracy": accs_test,
    "NLL": nlls_test,
})
display(df_test)
# Out:
#    Test Samples (MC)  Accuracy       NLL
# 0                  1    0.8647  0.446452
# 1                  2    0.8693  0.431564
# 2                  4    0.8711  0.426020
# 3                  8    0.8705  0.420931
# 4                 16    0.8707  0.419123
# 5                 32    0.8707  0.418490

# %%
# ============================================================
# Helper for consistent plotting style
# ============================================================
def plot_panel(ax, x, y, title, xlabel, ylabel, color=None):
    ax.plot(x, y, marker="o", color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(True)

# %%
# ============================================================
# Figure 1 — Test-time MC sweep
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

plot_panel(
    axes[0], test_samples_list, accs_test,
    "Accuracy vs Test-time MC Samples",
    "MC Samples at Test Time",
    "Accuracy"
)

plot_panel(
    axes[1], test_samples_list, nlls_test,
    "NLL vs Test-time MC Samples",
    "MC Samples at Test Time",
    "NLL",
    color="orange"
)

plt.suptitle("Effect of Monte Carlo Sampling at Test Time (IVON)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# --------------------------------------------------------------
# 4. Figure 4 — Bottom row: Varying train_samples
# --------------------------------------------------------------
# --------------------------------------------------------------
# Train-time sampling sweep WITHOUT retraining train_samples=1
# --------------------------------------------------------------

# 1. Evaluate the already-trained model (train_samples = 1)
metrics_1 = evaluate_all_metrics(
    model_ivon,
    optimizer_ivon,
    test_loader,
    device,
    test_samples=0   # evaluate @ mean
)

accs_train = [metrics_1["Top-1 Acc ↑"]]
nlls_train = [metrics_1["NLL ↓"]]
train_samples_list_done = [1]

print(f"train_samples=1 → Acc={accs_train[-1]:.4f}, NLL={nlls_train[-1]:.4f}")
# Out:
# train_samples=1 → Acc=0.8704, NLL=0.4317

# %%
# 2. Define the remaining training-sample values
train_samples_list_remaining = [2, 4, 8]

# 3. Train and evaluate ONLY the missing ones
for s in train_samples_list_remaining:

    print(f"\nTraining IVON with train_samples = {s} ...")
    model_s, opt_s = train_ivon(train_samples=s, epochs=NUMB_EPOCHS)

    # Evaluate using posterior mean
    metrics = evaluate_all_metrics(
        model_s,
        opt_s,
        test_loader,
        device,
        test_samples=0
    )

    accs_train.append(metrics["Top-1 Acc ↑"])
    nlls_train.append(metrics["NLL ↓"])
    train_samples_list_done.append(s)

    print(f"train_samples={s} → Acc={accs_train[-1]:.4f}, NLL={nlls_train[-1]:.4f}")

# 4. Build final DataFrame
df_train = pd.DataFrame({
    "Train Samples (MC)": train_samples_list_done,
    "Accuracy": accs_train,
    "NLL": nlls_train,
})

display(df_train)
# Out:
# Training IVON with train_samples = 8 ...
# train_samples=8 → Acc=0.8842, NLL=0.3721
#    Train Samples (MC)  Accuracy       NLL
# 0                   1    0.8704  0.431700
# 1                   2    0.8769  0.392000
# 2                   4    0.8837  0.397000
# 3                   8    0.8842  0.372095

# %%
# ============================================================
# Figure — Train-time MC sweep
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

plot_panel(
    axes[0], train_samples_list_done, accs_train,
    "Accuracy vs Train-time MC Samples",
    "MC Samples at Train Time",
    "Accuracy"
)

plot_panel(
    axes[1], train_samples_list_done, nlls_train,
    "NLL vs Train-time MC Samples",
    "MC Samples at Train Time",
    "NLL",
    color="orange"
)

plt.suptitle("Effect of Monte Carlo Sampling at Train Time (IVON)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# ============================================================
# Data extracted from screenshots
# ============================================================

# Test-time MC sweep
test_samples_list = [1, 2, 4, 8, 16, 32]
accs_test =        [0.8647, 0.8693, 0.8711, 0.8705, 0.8707, 0.8707]
nlls_test =        [0.446452, 0.431564, 0.426020, 0.420931, 0.419123, 0.418490]

# Train-time MC sweep
train_samples_list_done = [1, 2, 4, 8]
accs_train =              [0.8704, 0.8769, 0.8837, 0.8842]
nlls_train =              [0.431700, 0.392000, 0.397000, 0.372095]


# ============================================================
# Helper for consistent plotting style
# ============================================================
def plot_panel(ax, x, y, title, xlabel, ylabel, color=None):
    ax.plot(x, y, marker="o", color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(True)


# ============================================================
# Figure 1 — Test-time MC sweep
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

plot_panel(
    axes[0], test_samples_list, accs_test,
    "Accuracy vs Test-time MC Samples",
    "MC Samples at Test Time",
    "Accuracy"
)

plot_panel(
    axes[1], test_samples_list, nlls_test,
    "NLL vs Test-time MC Samples",
    "MC Samples at Test Time",
    "NLL",
    color="orange"
)

plt.suptitle("Effect of Monte Carlo Sampling at Test Time (IVON)", fontsize=14)
plt.tight_layout()
plt.savefig("test_time_mc.pdf", bbox_inches="tight")

plt.show()


# ============================================================
# Figure 2 — Train-time MC sweep
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

plot_panel(
    axes[0], train_samples_list_done, accs_train,
    "Accuracy vs Train-time MC Samples",
    "MC Samples at Train Time",
    "Accuracy"
)

plot_panel(
    axes[1], train_samples_list_done, nlls_train,
    "NLL vs Train-time MC Samples",
    "MC Samples at Train Time",
    "NLL",
    color="orange"
)

plt.suptitle("Effect of Monte Carlo Sampling at Train Time (IVON)", fontsize=14)
plt.tight_layout()
plt.savefig("train_time_mc.pdf", bbox_inches="tight")

plt.show()

# %%
# If in Google Colab:
from google.colab import files
files.download("test_time_mc.pdf")

# %% [markdown]
# ## Out-of-Distribution and In-Between Uncertainty Evaluation
# In the next cell, we evaluate the model on **SVHN**, which serves as an out-of-distribution dataset relative to CIFAR-10.
# This reproduces the paper’s OOD uncertainty results—corresponding to **Figure 3(a)** and the detection metrics reported in **Table 3**.
# Moreover, we are going to test **class exclusion**, where specific CIFAR-10 classes are withheld during training to further examine the model’s uncertainty under intentional distribution gaps.
# Here we again use the same OOD uncertainty metrics to evaluate how effectively the model identifies excluded classes as uncertain.

# %% [markdown]
# Subtask: Load the SVHN test dataset and apply the same normalization as CIFAR-10, then create a PyTorch DataLoader for the SVHN test set to be used as an Out-of-Distribution dataset.

# %%
transform_svhn = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std), # Re-using CIFAR-10 mean and std
])

# Load the SVHN test dataset
svhn_dataset = torchvision.datasets.SVHN(
    root='./data',
    split='test',
    transform=transform_svhn,
    download=True
)

# Create a DataLoader for the SVHN test dataset
svhn_loader = torch.utils.data.DataLoader(
    svhn_dataset,
    batch_size=50,
    shuffle=False
)

print("SVHN test dataset loaded and DataLoader created.")
# Out:
# 100%|██████████| 64.3M/64.3M [00:12<00:00, 5.14MB/s]
# SVHN test dataset loaded and DataLoader created.

# %% [markdown]
# ### Class-Exclusion Experiment Pipeline
#
# The following three code cells implement a full **class-exclusion uncertainty experiment** on CIFAR-10 using the IVON optimizer. First, we build custom datasets using `ExcludedClassDataset`, which filters out selected classes (e.g., *airplane* and *automobile*) from training while creating separate test sets for included and excluded classes. Second, we construct DataLoaders for these splits and train a ResNet-20 model **only on the remaining CIFAR-10 classes**, ensuring the excluded classes are completely unseen during training. Finally, we evaluate the trained model by computing predictive entropy via Monte Carlo sampling on three datasets—**included CIFAR-10 classes**, **excluded CIFAR-10 classes**, and **SVHN**—and generate uncertainty plots and OOD-style metrics to compare how the model behaves on seen, unseen, and external data.

# %%
# Define CIFAR-10 class_names
cifar10_class_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'
]

# Create a custom PyTorch Dataset class called ExcludedClassDataset
class FilteredClassDataset(Dataset):
    def __init__(self, original_dataset, excluded_classes_by_name, return_excluded=False):
        self.original_dataset = original_dataset
        self.return_excluded = return_excluded

        # Build class-name → index mapping
        self.class_to_idx = {name: i for i, name in enumerate(cifar10_class_names)}
        self.excluded_class_indices = {self.class_to_idx[name] for name in excluded_classes_by_name}

        # Prefer using targets for speed
        if hasattr(original_dataset, "targets"):
            labels = original_dataset.targets
        else:
            # fallback (slow)
            labels = [original_dataset[i][1] for i in range(len(original_dataset))]

        # Filter indices
        self.filtered_indices = []
        included_labels = set()

        for i, label in enumerate(labels):
            is_excluded = label in self.excluded_class_indices

            if (is_excluded and return_excluded) or (not is_excluded and not return_excluded):
                self.filtered_indices.append(i)
                if not return_excluded:
                    included_labels.add(label)

        # Build label mapping for included classes
        self.label_mapping = None
        if not return_excluded:
            sorted_labels = sorted(included_labels)
            self.label_mapping = {old: new for new, old in enumerate(sorted_labels)}

    def __len__(self):
        return len(self.filtered_indices)

    def __getitem__(self, idx):
        original_idx = self.filtered_indices[idx]
        img, label = self.original_dataset[original_idx]

        if self.label_mapping:
            label = self.label_mapping[label]

        return img, label

# %%
# ============================================================
# Part 1 — Create datasets for class exclusion setup
# ============================================================

# These classes will be removed from training,
# but they are still normal CIFAR-10 classes (NOT real OOD).
excluded_classes_for_ood = ['airplane', 'automobile']

print("Preparing datasets using ExcludedClassDataset...")
print(f"Excluded classes: {excluded_classes_for_ood}")
print("-" * 60)

# ------------------------------------------------------------
# Training set containing ONLY the included (non-excluded) classes
# ------------------------------------------------------------
cifar10_train_included = FilteredClassDataset(
    full_train_dataset,
    excluded_classes_by_name=excluded_classes_for_ood,
    return_excluded=False
)

print(f"[TRAIN INCLUDED] CIFAR-10 training data (excluded {', '.join(excluded_classes_for_ood)}): "
      f"{len(cifar10_train_included)} samples")

# ------------------------------------------------------------
# Test set containing ONLY the excluded classes
# (these are “class-OOD”, not true OOD)
# ------------------------------------------------------------
cifar10_test_excluded = FilteredClassDataset(
    test_dataset,
    excluded_classes_by_name=excluded_classes_for_ood,
    return_excluded=True
)

print(f"[TEST OOD] CIFAR-10 test data (only {', '.join(excluded_classes_for_ood)}): "
      f"{len(cifar10_test_excluded)} samples")

# ------------------------------------------------------------
# Test set containing ONLY the included (training) classes
# ------------------------------------------------------------
cifar10_test_included = FilteredClassDataset(
    test_dataset,
    excluded_classes_by_name=excluded_classes_for_ood,
    return_excluded=False
)

print(f"[TEST INCLUDED] CIFAR-10 test data (included classes only): "
      f"{len(cifar10_test_included)} samples")
print("-" * 60)
# Out:
# Preparing datasets using ExcludedClassDataset...
# Excluded classes: ['airplane', 'automobile']
# ------------------------------------------------------------
# [TRAIN INCLUDED] CIFAR-10 training data (excluded airplane, automobile): 40000 samples
# [TEST OOD] CIFAR-10 test data (only airplane, automobile): 2000 samples
# [TEST INCLUDED] CIFAR-10 test data (included classes only): 8000 samples
# ------------------------------------------------------------

# %%
# ============================================================
# Part 2 — Create DataLoaders and train IVON
# ============================================================

batch_size = 50
print(f"Creating DataLoaders (batch size = {batch_size})...")

# Training loader (included classes)
cifar10_train_included_loader = DataLoader(
    cifar10_train_included,
    batch_size=batch_size,
    shuffle=True
)
print("✔ DataLoader for TRAIN INCLUDED classes created.")

# Test loader (excluded classes — class-OOD)
cifar10_test_excluded_loader = DataLoader(
    cifar10_test_excluded,
    batch_size=batch_size,
    shuffle=False
)
print("✔ DataLoader for TEST EXCLUDED (OOD) classes created.")

# Test loader (included classes — in-domain)
cifar10_test_included_loader = DataLoader(
    cifar10_test_included,
    batch_size=batch_size,
    shuffle=False
)
print("✔ DataLoader for TEST INCLUDED (normal test) classes created.")
print("-" * 60)


# Train IVON on included classes
device = 'cuda' if torch.cuda.is_available() else 'cpu'

def train_ivon_excluded(model, optimizer, train_loader, device, epochs=10, train_samples=1):
    model.to(device)
    for epoch in range(epochs):
        model.train()
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            optimizer.zero_grad()
            for _ in range(train_samples):
                with optimizer.sampled_params(train=True):
                    logits = model(X)
                    loss = F.cross_entropy(logits, y)
                    loss.backward()
            optimizer.step()
        print(f"IVON (excluded classes) Epoch done: {epoch+1}")

model_ivon_excluded = ResNet20().to(device)

optimizer_ivon_excluded = ivon.IVON(
    model_ivon_excluded.parameters(),
    lr=0.1,
    ess=len(cifar10_train_included)
)

train_ivon_excluded(
    model_ivon_excluded,
    optimizer_ivon_excluded,
    cifar10_train_included_loader,
    device=device,
    epochs=NUMB_EPOCHS
)
# Out:
# Creating DataLoaders (batch size = 50)...
# ✔ DataLoader for TRAIN INCLUDED classes created.
# ✔ DataLoader for TEST EXCLUDED (OOD) classes created.
# ✔ DataLoader for TEST INCLUDED (normal test) classes created.
# ------------------------------------------------------------
# IVON (excluded classes) Epoch done: 1
# IVON (excluded classes) Epoch done: 2
# IVON (excluded classes) Epoch done: 3
# IVON (excluded classes) Epoch done: 4
# IVON (excluded classes) Epoch done: 5
# IVON (excluded classes) Epoch done: 6
# IVON (excluded classes) Epoch done: 7
# IVON (excluded classes) Epoch done: 8
# IVON (excluded classes) Epoch done: 9
# IVON (excluded classes) Epoch done: 10
# IVON (excluded classes) Epoch done: 11
# IVON (excluded classes) Epoch done: 12
# IVON (excluded classes) Epoch done: 13
# IVON (excluded classes) Epoch done: 14
# IVON (excluded classes) Epoch done: 15
# IVON (excluded classes) Epoch done: 16
# IVON (excluded classes) Epoch done: 17
# IVON (excluded classes) Epoch done: 18
# IVON (excluded classes) Epoch done: 19
# IVON (excluded classes) Epoch done: 20
# IVON (excluded classes) Epoch done: 21
# IVON (excluded classes) Epoch done: 22
# IVON (excluded classes) Epoch done: 23
# IVON (excluded classes) Epoch done: 24
# IVON (excluded classes) Epoch done: 25
# IVON (excluded classes) Epoch done: 26
# IVON (excluded classes) Epoch done: 27
# IVON (excluded classes) Epoch done: 28
# IVON (excluded classes) Epoch done: 29
# IVON (excluded classes) Epoch done: 30
# IVON (excluded classes) Epoch done: 31
# IVON (excluded classes) Epoch done: 32
# IVON (excluded classes) Epoch done: 33
# IVON (excluded classes) Epoch done: 34
# IVON (excluded classes) Epoch done: 35
# IVON (excluded classes) Epoch done: 36
# IVON (excluded classes) Epoch done: 37
# IVON (excluded classes) Epoch done: 38
# IVON (excluded classes) Epoch done: 39
# IVON (excluded classes) Epoch done: 40
# IVON (excluded classes) Epoch done: 41
# IVON (excluded classes) Epoch done: 42
# IVON (excluded classes) Epoch done: 43
# IVON (excluded classes) Epoch done: 44
# IVON (excluded classes) Epoch done: 45
# IVON (excluded classes) Epoch done: 46
# IVON (excluded classes) Epoch done: 47
# IVON (excluded classes) Epoch done: 48
# IVON (excluded classes) Epoch done: 49
# IVON (excluded classes) Epoch done: 50
# IVON (excluded classes) Epoch done: 51
# IVON (excluded classes) Epoch done: 52
# IVON (excluded classes) Epoch done: 53
# IVON (excluded classes) Epoch done: 54
# IVON (excluded classes) Epoch done: 55
# IVON (excluded classes) Epoch done: 56
# IVON (excluded classes) Epoch done: 57
# IVON (excluded classes) Epoch done: 58
# IVON (excluded classes) Epoch done: 59
# IVON (excluded classes) Epoch done: 60
# IVON (excluded classes) Epoch done: 61
# IVON (excluded classes) Epoch done: 62
# IVON (excluded classes) Epoch done: 63
# IVON (excluded classes) Epoch done: 64
# IVON (excluded classes) Epoch done: 65
# IVON (excluded classes) Epoch done: 66
# IVON (excluded classes) Epoch done: 67
# IVON (excluded classes) Epoch done: 68
# IVON (excluded classes) Epoch done: 69
# IVON (excluded classes) Epoch done: 70
# IVON (excluded classes) Epoch done: 71
# IVON (excluded classes) Epoch done: 72
# IVON (excluded classes) Epoch done: 73
# IVON (excluded classes) Epoch done: 74
# IVON (excluded classes) Epoch done: 75
# IVON (excluded classes) Epoch done: 76
# IVON (excluded classes) Epoch done: 77
# IVON (excluded classes) Epoch done: 78
# IVON (excluded classes) Epoch done: 79
# IVON (excluded classes) Epoch done: 80
# IVON (excluded classes) Epoch done: 81
# IVON (excluded classes) Epoch done: 82
# IVON (excluded classes) Epoch done: 83
# IVON (excluded classes) Epoch done: 84
# IVON (excluded classes) Epoch done: 85
# IVON (excluded classes) Epoch done: 86
# IVON (excluded classes) Epoch done: 87
# IVON (excluded classes) Epoch done: 88
# IVON (excluded classes) Epoch done: 89
# IVON (excluded classes) Epoch done: 90
# IVON (excluded classes) Epoch done: 91
# IVON (excluded classes) Epoch done: 92
# IVON (excluded classes) Epoch done: 93
# IVON (excluded classes) Epoch done: 94
# IVON (excluded classes) Epoch done: 95
# IVON (excluded classes) Epoch done: 96
# IVON (excluded classes) Epoch done: 97
# IVON (excluded classes) Epoch done: 98
# IVON (excluded classes) Epoch done: 99
# IVON (excluded classes) Epoch done: 100
# IVON (excluded classes) Epoch done: 101
# IVON (excluded classes) Epoch done: 102
# IVON (excluded classes) Epoch done: 103
# IVON (excluded classes) Epoch done: 104
# IVON (excluded classes) Epoch done: 105
# IVON (excluded classes) Epoch done: 106
# IVON (excluded classes) Epoch done: 107
# IVON (excluded classes) Epoch done: 108
# IVON (excluded classes) Epoch done: 109
# IVON (excluded classes) Epoch done: 110
# IVON (excluded classes) Epoch done: 111
# IVON (excluded classes) Epoch done: 112
# IVON (excluded classes) Epoch done: 113
# IVON (excluded classes) Epoch done: 114
# IVON (excluded classes) Epoch done: 115
# IVON (excluded classes) Epoch done: 116
# IVON (excluded classes) Epoch done: 117
# IVON (excluded classes) Epoch done: 118
# IVON (excluded classes) Epoch done: 119
# IVON (excluded classes) Epoch done: 120
# IVON (excluded classes) Epoch done: 121
# IVON (excluded classes) Epoch done: 122
# IVON (excluded classes) Epoch done: 123
# IVON (excluded classes) Epoch done: 124
# IVON (excluded classes) Epoch done: 125
# IVON (excluded classes) Epoch done: 126
# IVON (excluded classes) Epoch done: 127
# IVON (excluded classes) Epoch done: 128
# IVON (excluded classes) Epoch done: 129
# IVON (excluded classes) Epoch done: 130
# IVON (excluded classes) Epoch done: 131
# IVON (excluded classes) Epoch done: 132
# IVON (excluded classes) Epoch done: 133
# IVON (excluded classes) Epoch done: 134
# IVON (excluded classes) Epoch done: 135
# IVON (excluded classes) Epoch done: 136
# IVON (excluded classes) Epoch done: 137
# IVON (excluded classes) Epoch done: 138
# IVON (excluded classes) Epoch done: 139
# IVON (excluded classes) Epoch done: 140
# IVON (excluded classes) Epoch done: 141
# IVON (excluded classes) Epoch done: 142
# IVON (excluded classes) Epoch done: 143
# IVON (excluded classes) Epoch done: 144
# IVON (excluded classes) Epoch done: 145
# IVON (excluded classes) Epoch done: 146
# IVON (excluded classes) Epoch done: 147
# IVON (excluded classes) Epoch done: 148
# IVON (excluded classes) Epoch done: 149
# IVON (excluded classes) Epoch done: 150

# %%
# ============================================================
# Train SGD
# ============================================================

def train_sgd(model, optimizer, train_loader, device, epochs=NUMB_EPOCHS):
    model.to(device)

    for epoch in range(epochs):
        model.train()
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X)
            loss = F.cross_entropy(logits, y)
            loss.backward()
            optimizer.step()

        print(f"SGD (excluded classes) Epoch done: {epoch+1}")


model_sgd = ResNet20().to(device)
optimizer_sgd = torch.optim.SGD(model_sgd.parameters(), lr=0.1)

train_sgd(model_sgd, optimizer_sgd, cifar10_train_included_loader, device=device, epochs=NUMB_EPOCHS)
# Out:
# SGD (excluded classes) Epoch done: 1
# SGD (excluded classes) Epoch done: 2
# SGD (excluded classes) Epoch done: 3
# SGD (excluded classes) Epoch done: 4
# SGD (excluded classes) Epoch done: 5
# SGD (excluded classes) Epoch done: 6
# SGD (excluded classes) Epoch done: 7
# SGD (excluded classes) Epoch done: 8
# SGD (excluded classes) Epoch done: 9
# SGD (excluded classes) Epoch done: 10
# SGD (excluded classes) Epoch done: 11
# SGD (excluded classes) Epoch done: 12
# SGD (excluded classes) Epoch done: 13
# SGD (excluded classes) Epoch done: 14
# SGD (excluded classes) Epoch done: 15
# SGD (excluded classes) Epoch done: 16
# SGD (excluded classes) Epoch done: 17
# SGD (excluded classes) Epoch done: 18
# SGD (excluded classes) Epoch done: 19
# SGD (excluded classes) Epoch done: 20
# SGD (excluded classes) Epoch done: 21
# SGD (excluded classes) Epoch done: 22
# SGD (excluded classes) Epoch done: 23
# SGD (excluded classes) Epoch done: 24
# SGD (excluded classes) Epoch done: 25
# SGD (excluded classes) Epoch done: 26
# SGD (excluded classes) Epoch done: 27
# SGD (excluded classes) Epoch done: 28
# SGD (excluded classes) Epoch done: 29
# SGD (excluded classes) Epoch done: 30
# SGD (excluded classes) Epoch done: 31
# SGD (excluded classes) Epoch done: 32
# SGD (excluded classes) Epoch done: 33
# SGD (excluded classes) Epoch done: 34
# SGD (excluded classes) Epoch done: 35
# SGD (excluded classes) Epoch done: 36
# SGD (excluded classes) Epoch done: 37
# SGD (excluded classes) Epoch done: 38
# SGD (excluded classes) Epoch done: 39
# SGD (excluded classes) Epoch done: 40
# SGD (excluded classes) Epoch done: 41
# SGD (excluded classes) Epoch done: 42
# SGD (excluded classes) Epoch done: 43
# SGD (excluded classes) Epoch done: 44
# SGD (excluded classes) Epoch done: 45
# SGD (excluded classes) Epoch done: 46
# SGD (excluded classes) Epoch done: 47
# SGD (excluded classes) Epoch done: 48
# SGD (excluded classes) Epoch done: 49
# SGD (excluded classes) Epoch done: 50
# SGD (excluded classes) Epoch done: 51
# SGD (excluded classes) Epoch done: 52
# SGD (excluded classes) Epoch done: 53
# SGD (excluded classes) Epoch done: 54
# SGD (excluded classes) Epoch done: 55
# SGD (excluded classes) Epoch done: 56
# SGD (excluded classes) Epoch done: 57
# SGD (excluded classes) Epoch done: 58
# SGD (excluded classes) Epoch done: 59
# SGD (excluded classes) Epoch done: 60
# SGD (excluded classes) Epoch done: 61
# SGD (excluded classes) Epoch done: 62
# SGD (excluded classes) Epoch done: 63
# SGD (excluded classes) Epoch done: 64
# SGD (excluded classes) Epoch done: 65
# SGD (excluded classes) Epoch done: 66
# SGD (excluded classes) Epoch done: 67
# SGD (excluded classes) Epoch done: 68
# SGD (excluded classes) Epoch done: 69
# SGD (excluded classes) Epoch done: 70
# SGD (excluded classes) Epoch done: 71
# SGD (excluded classes) Epoch done: 72
# SGD (excluded classes) Epoch done: 73
# SGD (excluded classes) Epoch done: 74
# SGD (excluded classes) Epoch done: 75
# SGD (excluded classes) Epoch done: 76
# SGD (excluded classes) Epoch done: 77
# SGD (excluded classes) Epoch done: 78
# SGD (excluded classes) Epoch done: 79
# SGD (excluded classes) Epoch done: 80
# SGD (excluded classes) Epoch done: 81
# SGD (excluded classes) Epoch done: 82
# SGD (excluded classes) Epoch done: 83
# SGD (excluded classes) Epoch done: 84
# SGD (excluded classes) Epoch done: 85
# SGD (excluded classes) Epoch done: 86
# SGD (excluded classes) Epoch done: 87
# SGD (excluded classes) Epoch done: 88
# SGD (excluded classes) Epoch done: 89
# SGD (excluded classes) Epoch done: 90
# SGD (excluded classes) Epoch done: 91
# SGD (excluded classes) Epoch done: 92
# SGD (excluded classes) Epoch done: 93
# SGD (excluded classes) Epoch done: 94
# SGD (excluded classes) Epoch done: 95
# SGD (excluded classes) Epoch done: 96
# SGD (excluded classes) Epoch done: 97
# SGD (excluded classes) Epoch done: 98
# SGD (excluded classes) Epoch done: 99
# SGD (excluded classes) Epoch done: 100
# SGD (excluded classes) Epoch done: 101
# SGD (excluded classes) Epoch done: 102
# SGD (excluded classes) Epoch done: 103
# SGD (excluded classes) Epoch done: 104
# SGD (excluded classes) Epoch done: 105
# SGD (excluded classes) Epoch done: 106
# SGD (excluded classes) Epoch done: 107
# SGD (excluded classes) Epoch done: 108
# SGD (excluded classes) Epoch done: 109
# SGD (excluded classes) Epoch done: 110
# SGD (excluded classes) Epoch done: 111
# SGD (excluded classes) Epoch done: 112
# SGD (excluded classes) Epoch done: 113
# SGD (excluded classes) Epoch done: 114
# SGD (excluded classes) Epoch done: 115
# SGD (excluded classes) Epoch done: 116
# SGD (excluded classes) Epoch done: 117
# SGD (excluded classes) Epoch done: 118
# SGD (excluded classes) Epoch done: 119
# SGD (excluded classes) Epoch done: 120
# SGD (excluded classes) Epoch done: 121
# SGD (excluded classes) Epoch done: 122
# SGD (excluded classes) Epoch done: 123
# SGD (excluded classes) Epoch done: 124
# SGD (excluded classes) Epoch done: 125
# SGD (excluded classes) Epoch done: 126
# SGD (excluded classes) Epoch done: 127
# SGD (excluded classes) Epoch done: 128
# SGD (excluded classes) Epoch done: 129
# SGD (excluded classes) Epoch done: 130
# SGD (excluded classes) Epoch done: 131
# SGD (excluded classes) Epoch done: 132
# SGD (excluded classes) Epoch done: 133
# SGD (excluded classes) Epoch done: 134
# SGD (excluded classes) Epoch done: 135
# SGD (excluded classes) Epoch done: 136
# SGD (excluded classes) Epoch done: 137
# SGD (excluded classes) Epoch done: 138
# SGD (excluded classes) Epoch done: 139
# SGD (excluded classes) Epoch done: 140
# SGD (excluded classes) Epoch done: 141
# SGD (excluded classes) Epoch done: 142
# SGD (excluded classes) Epoch done: 143
# SGD (excluded classes) Epoch done: 144
# SGD (excluded classes) Epoch done: 145
# SGD (excluded classes) Epoch done: 146
# SGD (excluded classes) Epoch done: 147
# SGD (excluded classes) Epoch done: 148
# SGD (excluded classes) Epoch done: 149
# SGD (excluded classes) Epoch done: 150

# %%
# ==============================================================
# Part 3 — Predictive Entropy, KDE Plots, and Unified Metrics
# ==============================================================

# --------------------------------------------------------------
# a1. Predictive Entropy Functions
# --------------------------------------------------------------

# IVON entropy (uses optimizer.sampled_params)
def predictive_entropy(logits_mc):
    probs = logits_mc.softmax(dim=-1)
    entropy_per_sample = -(probs * (probs + 1e-12).log()).sum(dim=-1)  # [S, B]
    return entropy_per_sample.mean(dim=0).cpu().numpy()                # [B]


def get_entropy_ivon(model, optimizer, loader, mc_samples=5):
    model.eval()
    all_entropies = []

    with torch.no_grad():
        for X, _ in loader:
            X = X.to(device)

            logits_list = []
            for _ in range(mc_samples):
                with optimizer.sampled_params(train=False):
                    logits_list.append(model(X))

            logits_mc = torch.stack(logits_list, dim=0)   # [S, B, C]
            entropy = predictive_entropy(logits_mc)
            all_entropies.append(entropy)

    return np.concatenate(all_entropies)  # [N]


# SGD entropy (deterministic forward pass)
def get_entropy_sgd(model, loader):
    model.eval()
    all_entropies = []

    with torch.no_grad():
        for X, _ in loader:
            X = X.to(device)
            logits = model(X)
            probs = logits.softmax(dim=-1)
            entropy = -(probs * (probs + 1e-12).log()).sum(dim=-1)  # [B]
            all_entropies.append(entropy.cpu().numpy())

    return np.concatenate(all_entropies)


# --------------------------------------------------------------
# a2. Compute All Entropies (IVON & SGD)
# --------------------------------------------------------------

# ---- IVON ----
entropy_included_ivon = get_entropy_ivon(model_ivon_excluded, optimizer_ivon_excluded, cifar10_test_included_loader)
entropy_excluded_ivon = get_entropy_ivon(model_ivon_excluded, optimizer_ivon_excluded, cifar10_test_excluded_loader)
entropy_svhn_ivon     = get_entropy_ivon(model_ivon_excluded, optimizer_ivon_excluded, svhn_loader)

# ---- SGD ----
entropy_included_sgd = get_entropy_sgd(model_sgd, cifar10_test_included_loader)
entropy_excluded_sgd = get_entropy_sgd(model_sgd, cifar10_test_excluded_loader)
entropy_svhn_sgd     = get_entropy_sgd(model_sgd, svhn_loader)


# --------------------------------------------------------------
# Combined KDE Plot — IVON vs SGD (Included / Excluded / SVHN)
# --------------------------------------------------------------

plt.figure(figsize=(8,6))

# ---------------- IVON ----------------
sns.kdeplot(entropy_included_ivon, fill=True, alpha=0.45, label="Included (IVON)")
sns.kdeplot(entropy_excluded_ivon, fill=True, alpha=0.35, label="Excluded (IVON)")
sns.kdeplot(entropy_svhn_ivon,     fill=True, alpha=0.30, label="SVHN (IVON)")

# ---------------- SGD ----------------
sns.kdeplot(entropy_included_sgd, fill=True, alpha=0.45, label="Included (SGD)")
sns.kdeplot(entropy_excluded_sgd, fill=True, alpha=0.35, label="Excluded (SGD)")
sns.kdeplot(entropy_svhn_sgd,     fill=True, alpha=0.30, label="SVHN (SGD)")

plt.title("Predictive Entropy — IVON vs SGD", fontsize=14)
plt.xlabel("Entropy", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# ---- SAVE BEFORE SHOW ----
plt.tight_layout()
plt.savefig("entropy_ivon_vs_sgd.pdf", bbox_inches="tight")
plt.savefig("entropy_ivon_vs_sgd.png", dpi=300, bbox_inches="tight")

plt.show()

# Optional (Google Colab)
from google.colab import files
files.download("entropy_ivon_vs_sgd.pdf")

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5), sharey=True)

datasets = [
    ("Included", entropy_included_ivon, entropy_included_sgd),
    ("Excluded", entropy_excluded_ivon, entropy_excluded_sgd),
    ("SVHN",     entropy_svhn_ivon,     entropy_svhn_sgd),
]

colors = {
    "Included": "#1f77b4",  # blue
    "Excluded": "#ff7f0e",  # orange
    "SVHN":     "#2ca02c",  # green
}

# ---- IVON panel ----
for name, ivon_vals, _ in datasets:
    sns.kdeplot(ivon_vals, fill=True, alpha=0.5,
                label=name, color=colors[name], ax=axes[0])
axes[0].set_title("Predictive Entropy — IVON")
axes[0].set_xlabel("Entropy")
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# ---- SGD panel ----
for name, _, sgd_vals in datasets:
    sns.kdeplot(sgd_vals, fill=True, alpha=0.5,
                label=name, color=colors[name], ax=axes[1])
axes[1].set_title("Predictive Entropy — SGD")
axes[1].set_xlabel("Entropy")
axes[1].grid(True, alpha=0.3)
axes[1].legend()

plt.tight_layout()
plt.savefig("entropy_ivon_vs_sgd_panels.pdf", bbox_inches="tight")
plt.savefig("entropy_ivon_vs_sgd_panels.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
files.download("entropy_ivon_vs_sgd_panels.pdf")

# %% [markdown]
# ## OOD Detection Metrics
#
# ---
#
# ### **AUROC — Area Under the ROC Curve**
# Measures how well the score separates ID vs. OOD samples.
#
# $$
# \text{AUROC} = \int_{0}^{1} \text{TPR}(\text{FPR}) \, d\text{FPR}
# $$
#
# Equivalent interpretation:
#
# $$
# \text{AUROC} = \Pr\big(s_{\text{ood}} > s_{\text{in}}\big)
# $$
#
# Higher is better.
#
# ---
#
# ### **FPR@95 — False Positive Rate at 95% TPR**
# False positive rate when the true positive rate for OOD detection is 95%.
#
# Find threshold $ f^* $ such that:
#
# $$
# \text{TPR}(f^*) \approx 0.95
# $$
#
# Then report:
#
# $$
# \text{FPR@95} = \text{FPR}(f^*)
# $$
#
# Lower is better.
#
# ---
#
# ### **Detection Error**
# Minimum classification error assuming equal priors for ID and OOD.
#
# $$
# \text{Detection Error}
# = \min_f \left[ 0.5 \cdot \text{FPR}(f) + 0.5 \cdot \text{FNR}(f) \right]
# $$
#
# where
#
# $$
# \text{FNR}(f) = 1 - \text{TPR}(f)
# $$
#
# Lower is better.
#
# ---
#
# ### **AUPR-In — Area Under Precision–Recall (ID as Positive Class)**
# Precision–Recall AUC with **ID = positive**.
#
# $$
# \text{AUPR-In} = \int_0^1 \text{Precision}_{\text{in}}(r) \, dr
# $$
#
# Higher means better ID recognition.
#
# ---
#
# ### **AUPR-Out — Area Under Precision–Recall (OOD as Positive Class)**
# Precision–Recall AUC with **OOD = positive**.
#
# $$
# \text{AUPR-Out} = \int_0^1 \text{Precision}_{\text{out}}(r) \, dr
# $$
#
# Higher means better OOD detection.
#
# ---

# %%
# --------------------------------------------------------------
# b1. Metrics
# --------------------------------------------------------------
def compute_fpr95(scores_in, scores_ood):
    labels = np.concatenate([np.zeros_like(scores_in), np.ones_like(scores_ood)])
    scores = np.concatenate([scores_in, scores_ood])
    fprs, tprs, _ = roc_curve(labels, scores)
    idx = np.argmin(np.abs(tprs - 95/100))
    return fprs[idx]


def compute_detection_error(scores_in, scores_ood):
    labels = np.concatenate([np.zeros_like(scores_in), np.ones_like(scores_ood)])
    scores = np.concatenate([scores_in, scores_ood])
    fprs, tprs, _ = roc_curve(labels, scores)
    fnrs = 1 - tprs
    return np.min(0.5 * (fnrs + fprs))


def compute_aupr(scores_in, scores_ood):
    labels = np.concatenate([np.zeros_like(scores_in), np.ones_like(scores_ood)])
    scores = np.concatenate([scores_in, scores_ood])

    # AUPR-In (IN is positive class)
    prec_in, rec_in, _ = precision_recall_curve(1 - labels, -scores)
    aupr_in = auc(rec_in, prec_in)

    # AUPR-Out (OOD is positive class)
    prec_out, rec_out, _ = precision_recall_curve(labels, scores)
    aupr_out = auc(rec_out, prec_out)

    return aupr_in, aupr_out



# --------------------------------------------------------------
# b2. Metrics (AUROC, FPR@95, Detection Error, AUPR)
# --------------------------------------------------------------

def collect_metrics(ent_in, ent_ood):
    labels = np.concatenate([np.zeros_like(ent_in), np.ones_like(ent_ood)])
    scores = np.concatenate([ent_in, ent_ood])

    auroc = roc_auc_score(labels, scores)
    fpr95 = compute_fpr95(ent_in, ent_ood)
    det_err = compute_detection_error(ent_in, ent_ood)
    aupr_in, aupr_out = compute_aupr(ent_in, ent_ood)

    return auroc, fpr95, det_err, aupr_in, aupr_out



# --------------------------------------------------------------
# b3. Unified Comparison Table — IVON vs SGD
# --------------------------------------------------------------

rows = []

datasets = {
    "Excluded CIFAR-10": (
        entropy_excluded_ivon, entropy_excluded_sgd
    ),
    "SVHN": (
        entropy_svhn_ivon, entropy_svhn_sgd
    )
}

for name, (ent_ood_ivon, ent_ood_sgd) in datasets.items():

    metrics_ivon = collect_metrics(entropy_included_ivon, ent_ood_ivon)
    metrics_sgd  = collect_metrics(entropy_included_sgd,  ent_ood_sgd)

    rows.append({
        "Dataset": name,
        "IVON_AUROC":     metrics_ivon[0],
        "SGD_AUROC":      metrics_sgd[0],
        "IVON_FPR95":     metrics_ivon[1],
        "SGD_FPR95":      metrics_sgd[1],
        "IVON_DetErr":    metrics_ivon[2],
        "SGD_DetErr":     metrics_sgd[2],
        "IVON_AUPR-In":   metrics_ivon[3],
        "SGD_AUPR-In":    metrics_sgd[3],
        "IVON_AUPR-Out":  metrics_ivon[4],
        "SGD_AUPR-Out":   metrics_sgd[4],
    })

df_compare = pd.DataFrame(rows).set_index("Dataset")

print("========== UNIFIED OOD METRICS TABLE (IVON vs SGD) ==========")
display(df_compare.style.format("{:.4f}"))
# Out:
# ========== UNIFIED OOD METRICS TABLE (IVON vs SGD) ==========
# <style type="text/css">
# </style>
# <table id="T_4ee77" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ee77_level0_col0" class="col_heading level0 col0" >IVON_AUROC</th>
#       <th id="T_4ee77_level0_col1" class="col_heading level0 col1" >SGD_AUROC</th>
#       <th id="T_4ee77_level0_col2" class="col_heading level0 col2" >IVON_FPR95</th>
#       <th id="T_4ee77_level0_col3" class="col_heading level0 col3" >SGD_FPR95</th>
#       <th id="T_4ee77_level0_col4" class="col_heading level0 col4" >IVON_DetErr</th>
#       <th id="T_4ee77_level0_col5" class="col_heading level0 col5" >SGD_DetErr</th>
#       <th id="T_4ee77_level0_col6" class="col_heading level0 col6" >IVON_AUPR-In</th>
#       <th id="T_4ee77_level0_col7" class="col_heading level0 col7" >SGD_AUPR-In</th>
#       <th id="T_4ee77_level0_col8" class="col_heading level0 col8" >IVON_AUPR-Out</th>
#       <th id="T_4ee77_level0_col9" class="col_heading level0 col9" >SGD_AUPR-Out</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ee77_level0_row0" class="row_heading level0 row0" >Excluded CIFAR-10</th>
#       <td id="T_4ee77_row0_col0" class="data row0 col0" >0.6472</td>
#       <td id="T_4ee77_row0_col1" class="data row0 col1" >0.7129</td>
#       <td id="T_4ee77_row0_col2" class="data row0 col2" >0.8501</td>
#       <td id="T_4ee77_row0_col3" class="data row0 col3" >0.7736</td>
#       <td id="T_4ee77_row0_col4" class="data row0 col4" >0.3849</td>
#       <td id="T_4ee77_row0_col5" class="data row0 col5" >0.3373</td>
#       <td id="T_4ee77_row0_col6" class="data row0 col6" >0.8765</td>
#       <td id="T_4ee77_row0_col7" class="data row0 col7" >0.9051</td>
#       <td id="T_4ee77_row0_col8" class="data row0 col8" >0.2861</td>
#       <td id="T_4ee77_row0_col9" class="data row0 col9" >0.3555</td>
#     </tr>
#     <tr>
#       <th id="T_4ee77_level0_row1" class="row_heading level0 row1" >SVHN</th>
#       <td id="T_4ee77_row1_col0" class="data row1 col0" >0.9163</td>
#       <td id="T_4ee77_row1_col1" class="data row1 col1" >0.8698</td>
#       <td id="T_4ee77_row1_col2" class="data row1 col2" >0.2567</td>
#       <td id="T_4ee77_row1_col3" class="data row1 col3" >0.3142</td>
#       <td id="T_4ee77_row1_col4" class="data row1 col4" >0.1512</td>
#       <td id="T_4ee77_row1_col5" class="data row1 col5" >0.1791</td>
#       <td id="T_4ee77_row1_col6" class="data row1 col6" >0.8645</td>
#       <td id="T_4ee77_row1_col7" class="data row1 col7" >0.8161</td>
#       <td id="T_4ee77_row1_col8" class="data row1 col8" >0.9625</td>
#       <td id="T_4ee77_row1_col9" class="data row1 col9" >0.9295</td>
#     </tr>
#   </tbody>
# </table>
